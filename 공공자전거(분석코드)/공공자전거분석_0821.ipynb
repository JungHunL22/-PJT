# %%
import pandas as pd
import numpy as np
from glob import glob
import seaborn as sns
import matplotlib.pyplot as plt #그래프 패키지 모듈 등록
# %matplotlib inline 
#그래프는 show()함수를 통해서 독립창에서 실행되는 것이 원칙
#그래프를 콘솔에서 바로 작도되록 하는 설정
import matplotlib.pyplot as plt #그래프 패키지 모듈 등록
# %matplotlib inline 
#그래프는 show()함수를 통해서 독립창에서 실행되는 것이 원칙
#그래프를 콘솔에서 바로 작도되록 하는 설정
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
# 한글 문제
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
# 모든데이터 출력
#pd.set_option('display.max_rows',None)

# %%
df=glob('data/서울특별시 공공자전거 이용정보(시간대별)_20*.csv')
df_total=[]
for i in df:
    df_total.append(pd.read_csv(i,encoding='utf-8'))

# %%
# test=pd.concat(df_total,axis=0)

# %%
# test.to_csv('data/total.csv')

# %% [markdown]
# # 성별 및 연령대 *

# %%
# total.to_csv('data/total_1.csv')

# %%
test=pd.read_csv('data/total_1.csv',index_col=0)

# %%
g=pd.pivot_table(test,index='대여시간',columns='성별',values='이용건수',aggfunc='sum')

# %%
g['남']=g['m']+g['M']
g['여']=g['f']+g['F']

# %%
g2=g[['남','여']]

# %%
g2
# Out:
# 성별         남       여
# 대여시간
# 0     217069   67593
# 1     174322   41661
# 2     122217   25947
# 3      84474   16704
# 4      58434   12778
# 5      56562   19397
# 6     113134   41442
# 7     255249  119540
# 8     375161  236110
# 9     231112  154449
# 10    196312  137701
# 11    240947  166154
# 12    276670  199643
# 13    288330  220722
# 14    307960  243881
# 15    339506  268933
# 16    385638  306384
# 17    512367  378487
# 18    599549  450756
# 19    446665  331353
# 20    389026  292549
# 21    367171  256783
# 22    316523  192472
# 23    242683  114565

# %%
g2.plot()
# Out:
# <AxesSubplot:xlabel='대여시간'>

# %%
age=g=pd.pivot_table(test,index='대여시간',columns='연령대코드',values='이용건수',aggfunc='sum')
age
# Out:
# 연령대코드      20대     30대     40대     50대    60대  70대~    ~10대
# 대여시간
# 0       343585  107050   63135   58262  16528  2280   59314
# 1       235345   73643   58360   66709  20557  2540   39575
# 2       152502   46509   43529   54673  17721  1939   23611
# 3        94952   31563   33549   42242  14017  1450   15063
# 4        61917   23561   24898   28398   9186   822    9523
# 5        60592   33718   29274   24814   8564  1296    7066
# 6        94621   75803   75610   46845  14483  2226    9439
# 7       221756  209831  176366   97656  20792  2997   31785
# 8       471201  366234  242871  115620  22970  4367   20967
# 9       323734  206524  133444   77363  21016  4601   21826
# 10      284941  164194  114785   69810  21701  4983   25567
# 11      346722  202960  143470   76957  22768  5257   31678
# 12      427110  237069  159221   84191  22726  4547   42215
# 13      483685  244728  164333   89409  24913  5239   53334
# 14      548040  256050  174727   94187  27545  5752   67325
# ...

# %%
age.plot()
# Out:
# <AxesSubplot:xlabel='대여시간'>

# %% [markdown]
# # 연습

# %%
data=pd.read_csv('data/data.csv',index_col=0)
data
# Out:
#             대여일자  대여시간  이용건수
# 0     2020-01-01     0   599
# 1     2020-01-01     1   847
# 2     2020-01-01     2   748
# 3     2020-01-01     3   472
# 4     2020-01-01     4   344
# ...          ...   ...   ...
# 8760  2020-12-31    19  1340
# 8761  2020-12-31    20  1062
# 8762  2020-12-31    21   900
# 8763  2020-12-31    22   537
# 8764  2020-12-31    23   459
#
# [8765 rows x 3 columns]

# %%
whether=pd.read_csv('data/whether.csv',encoding='cp949')
whether
# Out:
#        지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm)
# 0     108  서울  2020-01-01 00:00    -6.5      0.0      0.0     NaN
# 1     108  서울  2020-01-01 01:00    -5.9      NaN      1.7     NaN
# 2     108  서울  2020-01-01 02:00    -5.7      NaN      0.1     NaN
# 3     108  서울  2020-01-01 03:00    -5.6      0.0      0.0     NaN
# 4     108  서울  2020-01-01 04:00    -5.4      NaN      0.0     NaN
# ...   ...  ..               ...     ...      ...      ...     ...
# 8779  108  서울  2020-12-31 19:00    -7.1      NaN      2.4     NaN
# 8780  108  서울  2020-12-31 20:00    -7.1      NaN      3.2     NaN
# 8781  108  서울  2020-12-31 21:00    -7.2      NaN      2.7     NaN
# 8782  108  서울  2020-12-31 22:00    -7.4      NaN      2.5     NaN
# 8783  108  서울  2020-12-31 23:00    -7.6      NaN      2.2     NaN
#
# [8784 rows x 7 columns]

# %%
b=pd.pivot_table(data,index=['대여일자'],aggfunc='count')
b[b['대여시간']!=24]
# Out:
#             대여시간  이용건수
# 대여일자
# 2020-08-26    19    19
# 2020-08-27    10    10

# %%
data.head()
# Out:
#          대여일자  대여시간  이용건수
# 0  2020-01-01     0   599
# 1  2020-01-01     1   847
# 2  2020-01-01     2   748
# 3  2020-01-01     3   472
# 4  2020-01-01     4   344

# %%
data=pd.pivot_table(data,index='대여일자',values='이용건수',aggfunc='sum')
data
# Out:
#              이용건수
# 대여일자
# 2020-01-01  15799
# 2020-01-02  28418
# 2020-01-03  30318
# 2020-01-04  25061
# 2020-01-05  22504
# ...           ...
# 2020-12-27  36352
# 2020-12-28  46230
# 2020-12-29  35251
# 2020-12-30  22194
# 2020-12-31  24202
#
# [366 rows x 1 columns]

# %% [markdown]
# # 연습2

# %%
# *
whether=pd.read_csv('data/whether.csv',encoding='cp949')
whether
# Out:
#        지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm)
# 0     108  서울  2020-01-01 00:00    -6.5      0.0      0.0     NaN
# 1     108  서울  2020-01-01 01:00    -5.9      NaN      1.7     NaN
# 2     108  서울  2020-01-01 02:00    -5.7      NaN      0.1     NaN
# 3     108  서울  2020-01-01 03:00    -5.6      0.0      0.0     NaN
# 4     108  서울  2020-01-01 04:00    -5.4      NaN      0.0     NaN
# ...   ...  ..               ...     ...      ...      ...     ...
# 8779  108  서울  2020-12-31 19:00    -7.1      NaN      2.4     NaN
# 8780  108  서울  2020-12-31 20:00    -7.1      NaN      3.2     NaN
# 8781  108  서울  2020-12-31 21:00    -7.2      NaN      2.7     NaN
# 8782  108  서울  2020-12-31 22:00    -7.4      NaN      2.5     NaN
# 8783  108  서울  2020-12-31 23:00    -7.6      NaN      2.2     NaN
#
# [8784 rows x 7 columns]

# %%
# *
data=pd.read_csv('data/data.csv',index_col=0)
data
# Out:
#             대여일자  대여시간  이용건수
# 0     2020-01-01     0   599
# 1     2020-01-01     1   847
# 2     2020-01-01     2   748
# 3     2020-01-01     3   472
# 4     2020-01-01     4   344
# ...          ...   ...   ...
# 8760  2020-12-31    19  1340
# 8761  2020-12-31    20  1062
# 8762  2020-12-31    21   900
# 8763  2020-12-31    22   537
# 8764  2020-12-31    23   459
#
# [8765 rows x 3 columns]

# %%
t=[]
for i in data.대여시간:
    i=str(i)
    if len(i)==1:
        t.append('0'+i)
    else :
        t.append(i)

data['대여시간']=t
data
# Out:
#             대여일자 대여시간  이용건수
# 0     2020-01-01   00   599
# 1     2020-01-01   01   847
# 2     2020-01-01   02   748
# 3     2020-01-01   03   472
# 4     2020-01-01   04   344
# ...          ...  ...   ...
# 8760  2020-12-31   19  1340
# 8761  2020-12-31   20  1062
# 8762  2020-12-31   21   900
# 8763  2020-12-31   22   537
# 8764  2020-12-31   23   459
#
# [8765 rows x 3 columns]

# %%
date=[]
time=[]
for i in whether.일시:
    date.append(i.split(' ')[0])
    time.append(i.split(' ')[1].split(':')[0])
whether['대여일자']=date
whether['대여시간']=time
whether=whether.iloc[:,3:]
whether
# Out:
#       기온(°C)  강수량(mm)  풍속(m/s)  적설(cm)        대여일자 대여시간
# 0       -6.5      0.0      0.0     NaN  2020-01-01   00
# 1       -5.9      NaN      1.7     NaN  2020-01-01   01
# 2       -5.7      NaN      0.1     NaN  2020-01-01   02
# 3       -5.6      0.0      0.0     NaN  2020-01-01   03
# 4       -5.4      NaN      0.0     NaN  2020-01-01   04
# ...      ...      ...      ...     ...         ...  ...
# 8779    -7.1      NaN      2.4     NaN  2020-12-31   19
# 8780    -7.1      NaN      3.2     NaN  2020-12-31   20
# 8781    -7.2      NaN      2.7     NaN  2020-12-31   21
# 8782    -7.4      NaN      2.5     NaN  2020-12-31   22
# 8783    -7.6      NaN      2.2     NaN  2020-12-31   23
#
# [8784 rows x 6 columns]

# %%
data_1=pd.merge(data,whether,how='left',on=['대여일자','대여시간'])

# %%
data_1
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm)
# 0     2020-01-01   00   599    -6.5      0.0      0.0     NaN
# 1     2020-01-01   01   847    -5.9      NaN      1.7     NaN
# 2     2020-01-01   02   748    -5.7      NaN      0.1     NaN
# 3     2020-01-01   03   472    -5.6      0.0      0.0     NaN
# 4     2020-01-01   04   344    -5.4      NaN      0.0     NaN
# ...          ...  ...   ...     ...      ...      ...     ...
# 8760  2020-12-31   19  1340    -7.1      NaN      2.4     NaN
# 8761  2020-12-31   20  1062    -7.1      NaN      3.2     NaN
# 8762  2020-12-31   21   900    -7.2      NaN      2.7     NaN
# 8763  2020-12-31   22   537    -7.4      NaN      2.5     NaN
# 8764  2020-12-31   23   459    -7.6      NaN      2.2     NaN
#
# [8765 rows x 7 columns]

# %%
data_1.isnull().sum()
data_1[data_1['기온(°C)'].isnull()]
# Out:
# 대여일자          0
# 대여시간          0
# 이용건수          0
# 기온(°C)        1
# 강수량(mm)    7721
# 풍속(m/s)       0
# 적설(cm)     8557
# dtype: int64
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm)
# 5725  2020-08-26   13  2242     NaN      NaN      4.3     NaN

# %%
data_1[data_1['대여일자']=='2020-08-26']
#['기온(°C)']
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm)
# 5712  2020-08-26   00  2457    28.7      NaN      2.7     NaN
# 5713  2020-08-26   01  1893    28.4      NaN      2.1     NaN
# 5714  2020-08-26   02  1234    28.1      NaN      1.8     NaN
# 5715  2020-08-26   03   833    27.6      NaN      2.0     NaN
# 5716  2020-08-26   04   586    27.3      NaN      2.0     NaN
# 5717  2020-08-26   05   747    27.2      NaN      2.1     NaN
# 5718  2020-08-26   06  1672    27.0      NaN      2.9     NaN
# 5719  2020-08-26   07  3545    27.3      NaN      2.7     NaN
# 5720  2020-08-26   08  5304    28.6      NaN      2.7     NaN
# 5721  2020-08-26   09  2699    29.7      NaN      3.2     NaN
# 5722  2020-08-26   10  1958    31.4      NaN      3.5     NaN
# 5723  2020-08-26   11  2230    32.6      NaN      3.8     NaN
# 5724  2020-08-26   12  2317    33.3      NaN      3.0     NaN
# 5725  2020-08-26   13  2242     NaN      NaN      4.3     NaN
# ...

# %%
data_1['기온(°C)'].fillna(33.7,inplace=True)

# %%
data_1=data_1.fillna(0)
data_1.isnull().sum()
# Out:
# 대여일자       0
# 대여시간       0
# 이용건수       0
# 기온(°C)     0
# 강수량(mm)    0
# 풍속(m/s)    0
# 적설(cm)     0
# dtype: int64

# %%
# *
data_1['우천여부']=['no' if i==0 else 'yes' for i in data_1['강수량(mm)']]
data_1
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 우천여부
# 0     2020-01-01   00   599    -6.5      0.0      0.0     0.0   no
# 1     2020-01-01   01   847    -5.9      0.0      1.7     0.0   no
# 2     2020-01-01   02   748    -5.7      0.0      0.1     0.0   no
# 3     2020-01-01   03   472    -5.6      0.0      0.0     0.0   no
# 4     2020-01-01   04   344    -5.4      0.0      0.0     0.0   no
# ...          ...  ...   ...     ...      ...      ...     ...  ...
# 8760  2020-12-31   19  1340    -7.1      0.0      2.4     0.0   no
# 8761  2020-12-31   20  1062    -7.1      0.0      3.2     0.0   no
# 8762  2020-12-31   21   900    -7.2      0.0      2.7     0.0   no
# 8763  2020-12-31   22   537    -7.4      0.0      2.5     0.0   no
# 8764  2020-12-31   23   459    -7.6      0.0      2.2     0.0   no
#
# [8765 rows x 8 columns]

# %%
data_1['시간대']=['출/퇴근' if i=='07' or i=='08' or i=='09' or i=='17' or i=='18' or i=='19' else '출/퇴근 외' for i in data_1['대여시간']]
data_1
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 우천여부     시간대
# 0     2020-01-01   00   599    -6.5      0.0      0.0     0.0   no  출/퇴근 외
# 1     2020-01-01   01   847    -5.9      0.0      1.7     0.0   no  출/퇴근 외
# 2     2020-01-01   02   748    -5.7      0.0      0.1     0.0   no  출/퇴근 외
# 3     2020-01-01   03   472    -5.6      0.0      0.0     0.0   no  출/퇴근 외
# 4     2020-01-01   04   344    -5.4      0.0      0.0     0.0   no  출/퇴근 외
# ...          ...  ...   ...     ...      ...      ...     ...  ...     ...
# 8760  2020-12-31   19  1340    -7.1      0.0      2.4     0.0   no    출/퇴근
# 8761  2020-12-31   20  1062    -7.1      0.0      3.2     0.0   no  출/퇴근 외
# 8762  2020-12-31   21   900    -7.2      0.0      2.7     0.0   no  출/퇴근 외
# 8763  2020-12-31   22   537    -7.4      0.0      2.5     0.0   no  출/퇴근 외
# 8764  2020-12-31   23   459    -7.6      0.0      2.2     0.0   no  출/퇴근 외
#
# [8765 rows x 9 columns]

# %% [markdown]
# # 계절별,시간별

# %%
월=[i.split('-')[1] for i in data_1['대여일자']]
data_1['월']=월

# %%
s=[]
for i in 월:
    if i=='03' or i=='04' or i=='05':
        s.append('봄')
    elif i=='06' or i=='07' or i=='08':
        s.append('여름')
    
    elif i=='09' or i=='10' or i=='11':
        s.append('가을')
    else:
        s.append('겨울')
data_1['계절']=s

# %%
# a=pd.pivot_table(data_1,index='시간대',values='이용건수')
# b=pd.pivot_table(data_1,index='계절',values='이용건수')

sns.boxplot(x=data_1['계절'],y=data_1['이용건수'])
# Out:
# <AxesSubplot:xlabel='계절', ylabel='이용건수'>

# %%
sns.histplot(x=data_1['대여시간'],y=data_1['이용건수'])
#sns.kdeplot(x=data_1['이용건수'])
# Out:
# <AxesSubplot:xlabel='대여시간', ylabel='이용건수'>

# %%
a=pd.pivot_table(data_1,index=['대여시간','시간대'],values='이용건수').sort_values('대여시간').reset_index()
a
# Out:
#    대여시간     시간대         이용건수
# 0    00  출/퇴근 외  1781.243836
# 1    01  출/퇴근 외  1360.901370
# 2    02  출/퇴근 외   932.832877
# 3    03  출/퇴근 외   637.906849
# 4    04  출/퇴근 외   433.712329
# 5    05  출/퇴근 외   452.942466
# 6    06  출/퇴근 외   874.046575
# 7    07    출/퇴근  2085.432877
# 8    08    출/퇴근  3408.849315
# 9    09    출/퇴근  2160.295890
# 10   10  출/퇴근 외  1879.400000
# 11   11  출/퇴근 외  2273.457534
# 12   12  출/퇴근 외  2676.928767
# 13   13  출/퇴근 외  2919.564384
# 14   14  출/퇴근 외  3206.628415
# 15   15  출/퇴근 외  3566.816940
# 16   16  출/퇴근 외  4069.510929
# 17   17    출/퇴근  5210.625683
# 18   18    출/퇴근  6076.013661
# 19   19    출/퇴근  4578.610959
# 20   20  출/퇴근 외  4054.282192
# 21   21  출/퇴근 외  3747.076712
# 22   22  출/퇴근 외  3110.712329
# 23   23  출/퇴근 외  2199.789041

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=a['대여시간'],y=a['이용건수'],hue='시간대',data=a)
plt.show()
# Out:
# <AxesSubplot:xlabel='대여시간', ylabel='이용건수'>

# %%
time=a['시간대']!='출/퇴근'
time
no=np.logical_not(time)
a.대여시간[no][:3]
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18    False
# 19    False
# 20     True
# 21     True
# 22     True
# 23     True
# Name: 시간대, dtype: bool
# 7    07
# 8    08
# 9    09
# Name: 대여시간, dtype: object

# %%
plt.figure(figsize=(10,6))
plt.bar(list(a['대여시간']),a['이용건수'],label='출퇴근 외')
plt.bar(list(a.대여시간[no][:3]),a.이용건수[no][:3], color='red',label='출퇴근')
plt.bar(list(a.대여시간[no][3:]),a.이용건수[no][3:], color='red')
plt.legend()
plt.show()
# Out:
# <BarContainer object of 24 artists>
# <BarContainer object of 3 artists>
# <BarContainer object of 3 artists>

# %%
plt.figure(figsize=(10,6))
plt.bar(list(a['대여시간']),a['이용건수'],label='출퇴근 외',color='dodgerblue')
plt.bar(list(a.대여시간[no]),a.이용건수[no], color='red',label='출퇴근')
plt.legend()
plt.show()
# Out:
# <BarContainer object of 24 artists>
# <BarContainer object of 6 artists>

# %%
# *
plt.figure(figsize=(10,6))
plt.plot(a['대여시간'],a['이용건수'],marker='o')
plt.plot(a.대여시간[no][:3],a.이용건수[no][:3], color='red',marker='o',ms=7)
plt.plot(a.대여시간[no][3:],a.이용건수[no][3:], color='red',marker='o',ms=7)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data_1.groupby('우천여부').corr()

data_1.corr()
# Out:
#                   이용건수    기온(°C)   강수량(mm)   풍속(m/s)    적설(cm)
# 우천여부
# no   이용건수     1.000000  0.538021       NaN  0.213776 -0.113271
#      기온(°C)   0.538021  1.000000       NaN  0.075583 -0.224196
#      강수량(mm)       NaN       NaN       NaN       NaN       NaN
#      풍속(m/s)  0.213776  0.075583       NaN  1.000000  0.092089
#      적설(cm)  -0.113271 -0.224196       NaN  0.092089  1.000000
# yes  이용건수     1.000000  0.190052 -0.170942 -0.152042 -0.037664
#      기온(°C)   0.190052  1.000000  0.096862 -0.193157 -0.372591
#      강수량(mm) -0.170942  0.096862  1.000000  0.186861 -0.046318
#      풍속(m/s) -0.152042 -0.193157  0.186861  1.000000  0.062418
#      적설(cm)  -0.037664 -0.372591 -0.046318  0.062418  1.000000
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)    적설(cm)
# 이용건수     1.000000  0.467362 -0.133162  0.163428 -0.105771
# 기온(°C)   0.467362  1.000000  0.090725  0.075824 -0.225282
# 강수량(mm) -0.133162  0.090725  1.000000  0.100889 -0.009839
# ...

# %%
month=[]
for i in data_1['대여일자']:
    month.append(i.split('-')[1])
data_1['월']=month
data_1
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 우천여부   월  계절
# 0     2020-01-01   00   599    -6.5      0.0      0.0     0.0   no  01  겨울
# 1     2020-01-01   01   847    -5.9      0.0      1.7     0.0   no  01  겨울
# 2     2020-01-01   02   748    -5.7      0.0      0.1     0.0   no  01  겨울
# 3     2020-01-01   03   472    -5.6      0.0      0.0     0.0   no  01  겨울
# 4     2020-01-01   04   344    -5.4      0.0      0.0     0.0   no  01  겨울
# ...          ...  ...   ...     ...      ...      ...     ...  ...  ..  ..
# 8760  2020-12-31   19  1340    -7.1      0.0      2.4     0.0   no  12  겨울
# 8761  2020-12-31   20  1062    -7.1      0.0      3.2     0.0   no  12  겨울
# 8762  2020-12-31   21   900    -7.2      0.0      2.7     0.0   no  12  겨울
# 8763  2020-12-31   22   537    -7.4      0.0      2.5     0.0   no  12  겨울
# 8764  2020-12-31   23   459    -7.6      0.0      2.2     0.0   no  12  겨울
#
# [8765 rows x 10 columns]

# %%
season=['봄','여름','가을','겨울']
#r=data_fin[data_fin['우천여부']=='yes']
#r

s_total=[]
for i in range(4):
    s_total.append(data_1[data_1['계절']==season[i]])

# %%
s_total[0]
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 우천여부   월 계절
# 1440  2020-03-01   00   985     5.3      0.0      1.5     0.0   no  03  봄
# 1441  2020-03-01   01   833     5.2      0.0      2.0     0.0   no  03  봄
# 1442  2020-03-01   02   607     4.7      0.0      1.0     0.0   no  03  봄
# 1443  2020-03-01   03   443     4.3      0.0      0.6     0.0   no  03  봄
# 1444  2020-03-01   04   270     4.0      0.0      1.3     0.0   no  03  봄
# ...          ...  ...   ...     ...      ...      ...     ...  ...  .. ..
# 3643  2020-05-31   19  7015    20.7      0.0      5.3     0.0   no  05  봄
# 3644  2020-05-31   20  6737    20.2      0.0      3.0     0.0   no  05  봄
# 3645  2020-05-31   21  5603    19.8      0.0      2.6     0.0   no  05  봄
# 3646  2020-05-31   22  2797    19.0      0.0      2.9     0.0   no  05  봄
# 3647  2020-05-31   23   565    18.0      0.2      2.1     0.0  yes  05  봄
#
# [2208 rows x 10 columns]

# %%
for i in s_total:
    sum=pd.pivot_table(i,index='월',values='이용건수',aggfunc='sum')
    #sum

    rain=i[i['우천여부']=='yes']
    rain2=pd.pivot_table(rain,index=['월'],values=['우천여부'],aggfunc='count')
    #rain2

    temp=pd.pivot_table(i,index=['월'],values=['기온(°C)'])
    #temp
    
    a=pd.concat([sum,rain2,temp],axis=1)
    a
    a.corr()
#     temp.plot()
#     sum.plot()
#     rain2.plot()
# Out:
#        이용건수  우천여부     기온(°C)
# 월
# 03  1490825    12   7.669624
# 04  2108040    16  11.084028
# 05  2427680    83  18.006452
#             이용건수      우천여부    기온(°C)
# 이용건수    1.000000  0.793166  0.930561
# 우천여부    0.793166  1.000000  0.961069
# 기온(°C)  0.930561  0.961069  1.000000
#        이용건수  우천여부     기온(°C)
# 월
# 06  2725712    65  23.879861
# 07  2542943   114  24.134677
# 08  1709519   167  26.484828
#             이용건수      우천여부    기온(°C)
# 이용건수    1.000000 -0.945571 -0.996748
# 우천여부   -0.945571  1.000000  0.916272
# 기온(°C) -0.996748  0.916272  1.000000
#        이용건수  우천여부     기온(°C)
# 월
# 09  2763148  82.0  21.403611
# 10  2840128   NaN  14.300672
# 11  1956810  22.0   8.067639
#             이용건수  우천여부    기온(°C)
# 이용건수    1.000000   1.0  0.802102
# 우천여부    1.000000   1.0  1.000000
# 기온(°C)  0.802102   1.0  1.000000
#        이용건수  우천여부    기온(°C)
# 월
# 01   778073    18  1.627554
# 02   750132    31  2.525431
# 12  1178737     7 -0.300806
#             이용건수      우천여부    기온(°C)
# ...

# %% [markdown]
# # 강수량에 따른 시간/일별

# %%
data_1['일시']=data_1.대여일자+' '+data_1.대여시간

# %%
data_1[data_1['적설(cm)']!=0]
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 우천여부   월  계절  \
# 442   2020-01-19   10   441     1.0      0.0      0.7     0.3   no  01  겨울
# 835   2020-02-04   19   411     0.9      0.0      3.1     0.3   no  02  겨울
# 836   2020-02-04   20   538     0.0      0.0      4.7     0.7   no  02  겨울
# 837   2020-02-04   21   630    -1.3      1.5      6.1     0.7  yes  02  겨울
# 838   2020-02-04   22   775    -2.3      0.0      2.6     0.7   no  02  겨울
# ...          ...  ...   ...     ...      ...      ...     ...  ...  ..  ..
# 8439  2020-12-18   10  1064    -0.8      0.0      2.1     0.6   no  12  겨울
# 8440  2020-12-18   11  1332    -0.3      0.0      3.2     0.6   no  12  겨울
# 8441  2020-12-18   12  1602    -0.4      0.0      3.6     0.6   no  12  겨울
# 8442  2020-12-18   13  1642     0.8      0.0      3.2     0.6   no  12  겨울
# 8443  2020-12-18   14  1869     1.0      0.0      3.3     0.5   no  12  겨울
#
#                  일시
# 442   2020-01-19 10
# 835   2020-02-04 19
# ...

# %%
data_2=data_1[data_1['강수량(mm)']!=0]
data_3=data_2[data_2['계절']=='여름']

# %%
plt.plot(data_3['일시'],data_3['이용건수'])

# %%
data_3[data_3['이용건수']==max(data_3['이용건수'])]
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 우천여부   시간대  계절  \
# 5106  2020-07-31   18  9639    27.7      0.3      2.8     0.0  yes  출/퇴근  여름
#
#        월             일시
# 5106  07  2020-07-31 18

# %%
plt.plot(data_3['일시'],data_3['강수량(mm)'])

# %%
data_2.corr()
# Out:
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)    적설(cm)
# 이용건수     1.000000  0.190052 -0.170942 -0.152042 -0.037664
# 기온(°C)   0.190052  1.000000  0.096862 -0.193157 -0.372591
# 강수량(mm) -0.170942  0.096862  1.000000  0.186861 -0.046318
# 풍속(m/s) -0.152042 -0.193157  0.186861  1.000000  0.062418
# 적설(cm)  -0.037664 -0.372591 -0.046318  0.062418  1.000000

# %%
aa=pd.pivot_table(data_1,index='일시',values=['이용건수','강수량(mm)'])
bb=aa[aa['강수량(mm)']!=0]
bb
sns.scatterplot(x=aa['강수량(mm)'],y=aa['이용건수'],data=aa)
bb.corr()
# Out:
#                강수량(mm)  이용건수
# 일시
# 2020-01-01 12      0.1   588
# 2020-01-06 15      0.1   370
# 2020-01-06 18      0.6   453
# 2020-01-06 21      0.5   201
# 2020-01-07 00      0.6   256
# ...                ...   ...
# 2020-12-13 12      0.6   570
# 2020-12-13 15      0.4  1119
# 2020-12-18 06      0.2   362
# 2020-12-28 03      1.3   127
# 2020-12-29 15      0.2  1795
#
# [617 rows x 2 columns]
# <AxesSubplot:xlabel='강수량(mm)', ylabel='이용건수'>
#           강수량(mm)      이용건수
# 강수량(mm)  1.000000 -0.170942
# 이용건수    -0.170942  1.000000

# %%
cc=data_1[data_1['계절']=='여름']
dd=pd.pivot_table(cc,index='일시',values=['이용건수','강수량(mm)'])
dd
ee=dd[dd['강수량(mm)']!=0]
sns.scatterplot(x=ee['강수량(mm)'],y=ee['이용건수'],data=ee)
dd.corr()
# Out:
#                강수량(mm)  이용건수
# 일시
# 2020-06-01 00      0.8   790
# 2020-06-01 01      0.3   915
# 2020-06-01 02      0.0   688
# 2020-06-01 03      0.0   506
# 2020-06-01 04      0.0   352
# ...                ...   ...
# 2020-08-31 19      0.0  8195
# 2020-08-31 20      0.0  7632
# 2020-08-31 21      0.0  7128
# 2020-08-31 22      0.0  5118
# 2020-08-31 23      0.0  2982
#
# [2189 rows x 2 columns]
# <AxesSubplot:xlabel='강수량(mm)', ylabel='이용건수'>
#           강수량(mm)      이용건수
# 강수량(mm)  1.000000 -0.246798
# 이용건수    -0.246798  1.000000

# %% [markdown]
# # 연습 3(일별 통합)

# %%
data_ex1=pd.pivot_table(data_1,index='대여일자',values=['이용건수','강수량(mm)','적설(cm)'],aggfunc='sum')
data_ex2=pd.pivot_table(data_1,index='대여일자',values=['기온(°C)','풍속(m/s)'])

# %%
data_ex1,data_ex2
# Out:
# (            강수량(mm)   이용건수  적설(cm)
#  대여일자
#  2020-01-01      0.1  15799     0.0
#  2020-01-02      0.0  28418     0.0
#  2020-01-03      0.0  30318     0.0
#  2020-01-04      0.0  25061     0.0
#  2020-01-05      0.0  22504     0.0
#  ...             ...    ...     ...
#  2020-12-27      0.0  36352     0.0
#  2020-12-28      1.3  46230     0.0
#  2020-12-29      0.2  35251     0.0
#  2020-12-30      0.0  22194     0.0
#  2020-12-31      0.0  24202     0.0
#
#  [366 rows x 3 columns],
#                 기온(°C)   풍속(m/s)
#  대여일자
#  2020-01-01  -2.708333  1.104167
#  2020-01-02   0.987500  1.912500
#  2020-01-03   0.120833  1.879167
#  2020-01-04   1.054167  1.895833
#  2020-01-05   1.175000  1.045833
#  ...               ...       ...
#  2020-12-27   5.395833  1.850000
#  2020-12-28   6.920833  1.441667
#  2020-12-29   1.033333  2.733333
#  2020-12-30 -10.366667  4.037500
#  2020-12-31  -9.229167  2.529167
#
#  [366 rows x 2 columns])

# %%
data_fin=pd.concat([data_ex1,data_ex2],axis=1).reset_index()
data_fin['우천여부']=['no' if i==0 else 'yes' for i in data_fin['강수량(mm)']]
data_fin.head(30)
# Out:
#           대여일자  강수량(mm)   이용건수  적설(cm)    기온(°C)   풍속(m/s) 우천여부
# 0   2020-01-01      0.1  15799     0.0 -2.708333  1.104167  yes
# 1   2020-01-02      0.0  28418     0.0  0.987500  1.912500   no
# 2   2020-01-03      0.0  30318     0.0  0.120833  1.879167   no
# 3   2020-01-04      0.0  25061     0.0  1.054167  1.895833   no
# 4   2020-01-05      0.0  22504     0.0  1.175000  1.045833   no
# 5   2020-01-06      1.2  15160     0.0  2.725000  3.100000  yes
# 6   2020-01-07     39.8   1884     0.0  6.062500  4.183333  yes
# 7   2020-01-08     18.7  21186     0.0  3.137500  3.345833  yes
# 8   2020-01-09      0.0  28258     0.0 -0.900000  2.250000   no
# 9   2020-01-10      0.0  28891     0.0 -0.816667  1.566667   no
# 10  2020-01-11      0.0  22675     0.0 -0.033333  1.833333   no
# 11  2020-01-12      0.0  19330     0.0 -0.954167  2.450000   no
# 12  2020-01-13      0.0  26355     0.0 -2.645833  2.358333   no
# 13  2020-01-14      0.0  28051     0.0 -2.366667  1.579167   no
# ...

# %%
sel=[]
for i in range(len(data_fin)):
    if data_fin['강수량(mm)'][i]>0.5 or data_fin['적설(cm)'][i]>0.1:
        sel.append('yes')
    else:
        sel.append('no')
data_fin['우천여부2']=sel

# %%
data_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   대여일자     366 non-null    object
#  1   강수량(mm)  366 non-null    float64
#  2   이용건수     366 non-null    int64
#  3   적설(cm)   366 non-null    float64
#  4   기온(°C)   366 non-null    float64
#  5   풍속(m/s)  366 non-null    float64
#  6   우천여부     366 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 20.1+ KB

# %%
data_fin.corr()
# Out:
#           강수량(mm)      이용건수    적설(cm)    기온(°C)   풍속(m/s)
# 강수량(mm)  1.000000 -0.304282 -0.014740  0.231571  0.248152
# 이용건수    -0.304282  1.000000 -0.204059  0.616661 -0.166312
# 적설(cm)  -0.014740 -0.204059  1.000000 -0.256155  0.146340
# 기온(°C)   0.231571  0.616661 -0.256155  1.000000 -0.038333
# 풍속(m/s)  0.248152 -0.166312  0.146340 -0.038333  1.000000

# %%
#pd.pivot_table(data_fin,index='월',values='기온(°C)')

# %%
data_fin.groupby('우천여부2').corr()
# Out:
#                 강수량(mm)      이용건수    적설(cm)    기온(°C)   풍속(m/s)
# 우천여부2
# no    강수량(mm)  1.000000  0.027757       NaN  0.152497  0.157557
#       이용건수     0.027757  1.000000       NaN  0.838542 -0.053655
#       적설(cm)        NaN       NaN       NaN       NaN       NaN
#       기온(°C)   0.152497  0.838542       NaN  1.000000 -0.023946
#       풍속(m/s)  0.157557 -0.053655       NaN -0.023946  1.000000
# yes   강수량(mm)  1.000000 -0.275634 -0.178576  0.351877  0.230810
#       이용건수    -0.275634  1.000000 -0.267979  0.422777 -0.128293
#       적설(cm)  -0.178576 -0.267979  1.000000 -0.569340  0.152763
#       기온(°C)   0.351877  0.422777 -0.569340  1.000000 -0.203205
#       풍속(m/s)  0.230810 -0.128293  0.152763 -0.203205  1.000000

# %%
sns.scatterplot(x=data_fin['기온(°C)'],y=data_fin['이용건수'],hue=data_fin['우천여부2'])
sns.lmplot(x='기온(°C)',y='이용건수',hue='우천여부2',data=data_fin)
plt.show()
# Out:
# <AxesSubplot:xlabel='기온(°C)', ylabel='이용건수'>

# %%
# *
sns.scatterplot(x=data_fin['기온(°C)'],y=data_fin['이용건수'],hue=data_fin['우천여부'])
sns.lmplot(x='기온(°C)',y='이용건수',hue='우천여부',data=data_fin)
plt.show()
# Out:
# <AxesSubplot:xlabel='기온(°C)', ylabel='이용건수'>

# %%
sns.scatterplot(x=data_fin['풍속(m/s)'],y=data_fin['이용건수'],hue=data_fin['우천여부'])
sns.lmplot(x='풍속(m/s)',y='이용건수',hue='우천여부',data=data_fin)
plt.show()
# Out:
# <AxesSubplot:xlabel='풍속(m/s)', ylabel='이용건수'>

# %%
sns.scatterplot(x=data_fin['적설(cm)'],y=data_fin['이용건수'],hue=data_fin['우천여부'])
plt.show()
# Out:
# <AxesSubplot:xlabel='적설(cm)', ylabel='이용건수'>

# %%
data_fin[data_fin['적설(cm)']!=0]
# Out:
#            대여일자  강수량(mm)   이용건수  적설(cm)    기온(°C)   풍속(m/s) 우천여부
# 18   2020-01-19      0.6  17224     0.3  1.816667  2.104167  yes
# 34   2020-02-04      1.7  22678     3.1 -1.416667  2.858333  yes
# 35   2020-02-05      0.0  20073     7.0 -7.954167  3.341667   no
# 46   2020-02-16     15.1   6656    42.3 -0.570833  3.941667  yes
# 47   2020-02-17      1.0  13589    76.5 -5.641667  3.433333  yes
# 48   2020-02-18      0.0  24417    24.9 -4.275000  2.329167   no
# 347  2020-12-13      2.9  14137    36.5 -0.441667  2.837500  yes
# 348  2020-12-14      0.0  27657    31.1 -7.450000  3.354167   no
# 349  2020-12-15      0.0  27670    22.3 -8.266667  2.679167   no
# 350  2020-12-16      0.0  27329    17.8 -8.200000  2.616667   no
# 351  2020-12-17      0.0  31881    14.7 -5.487500  1.795833   no
# 352  2020-12-18      0.2  29787     8.2 -1.625000  2.933333  yes

# %%
sns.scatterplot(x=data_fin['강수량(mm)'],y=data_fin['이용건수'],hue=data_fin['우천여부'])
plt.show()
# Out:
# <AxesSubplot:xlabel='강수량(mm)', ylabel='이용건수'>

# %%
# sns.scatterplot(x=data_fin['일교차'],y=data_fin['이용건수'])
# plt.show()
a
# Out:
#        이용건수  우천여부    기온(°C)
# 월
# 01   778073    18  1.627554
# 11  1956810    22  8.067639
# 12  1178737     7 -0.300806

# %% [markdown]
# # 연습4

# %%
month=[]
for i in data_fin['대여일자']:
    month.append(i.split('-')[1])
data_fin['월']=month
data_fin
# Out:
#            대여일자  강수량(mm)   이용건수  적설(cm)     기온(°C)   풍속(m/s) 우천여부   월
# 0    2020-01-01      0.1  15799     0.0  -2.708333  1.104167  yes  01
# 1    2020-01-02      0.0  28418     0.0   0.987500  1.912500   no  01
# 2    2020-01-03      0.0  30318     0.0   0.120833  1.879167   no  01
# 3    2020-01-04      0.0  25061     0.0   1.054167  1.895833   no  01
# 4    2020-01-05      0.0  22504     0.0   1.175000  1.045833   no  01
# ..          ...      ...    ...     ...        ...       ...  ...  ..
# 361  2020-12-27      0.0  36352     0.0   5.395833  1.850000   no  12
# 362  2020-12-28      1.3  46230     0.0   6.920833  1.441667  yes  12
# 363  2020-12-29      0.2  35251     0.0   1.033333  2.733333  yes  12
# 364  2020-12-30      0.0  22194     0.0 -10.366667  4.037500   no  12
# 365  2020-12-31      0.0  24202     0.0  -9.229167  2.529167   no  12
#
# [366 rows x 8 columns]

# %%
월=[i.split('-')[1] for i in data_fin['대여일자']]

s=[]
for i in 월:
    if i=='03' or i=='04' or i=='05':
        s.append('봄')
    elif i=='06' or i=='07' or i=='08':
        s.append('여름')
    
    elif i=='09' or i=='10' or i=='11':
        s.append('가을')
    else:
        s.append('겨울')

# %%
data_fin['계절']=s
data_fin
# Out:
#            대여일자  강수량(mm)   이용건수  적설(cm)     기온(°C)   풍속(m/s) 우천여부   월  계절
# 0    2020-01-01      0.1  15799     0.0  -2.708333  1.104167  yes  01  겨울
# 1    2020-01-02      0.0  28418     0.0   0.987500  1.912500   no  01  겨울
# 2    2020-01-03      0.0  30318     0.0   0.120833  1.879167   no  01  겨울
# 3    2020-01-04      0.0  25061     0.0   1.054167  1.895833   no  01  겨울
# 4    2020-01-05      0.0  22504     0.0   1.175000  1.045833   no  01  겨울
# ..          ...      ...    ...     ...        ...       ...  ...  ..  ..
# 361  2020-12-27      0.0  36352     0.0   5.395833  1.850000   no  12  겨울
# 362  2020-12-28      1.3  46230     0.0   6.920833  1.441667  yes  12  겨울
# 363  2020-12-29      0.2  35251     0.0   1.033333  2.733333  yes  12  겨울
# 364  2020-12-30      0.0  22194     0.0 -10.366667  4.037500   no  12  겨울
# 365  2020-12-31      0.0  24202     0.0  -9.229167  2.529167   no  12  겨울
#
# [366 rows x 9 columns]

# %%
tp=pd.pivot_table(data_1,index=['대여일자'],values=['기온(°C)'],aggfunc=['max','min']).reset_index()
tp2=abs(tp['max']-tp['min'])
data_fin['일교차']=tp2['기온(°C)']
data_fin
# Out:
#            대여일자  강수량(mm)   이용건수  적설(cm)     기온(°C)   풍속(m/s) 우천여부   월  계절  일교차
# 0    2020-01-01      0.1  15799     0.0  -2.708333  1.104167  yes  01  겨울  6.8
# 1    2020-01-02      0.0  28418     0.0   0.987500  1.912500   no  01  겨울  4.5
# 2    2020-01-03      0.0  30318     0.0   0.120833  1.879167   no  01  겨울  7.6
# 3    2020-01-04      0.0  25061     0.0   1.054167  1.895833   no  01  겨울  8.8
# 4    2020-01-05      0.0  22504     0.0   1.175000  1.045833   no  01  겨울  9.6
# ..          ...      ...    ...     ...        ...       ...  ...  ..  ..  ...
# 361  2020-12-27      0.0  36352     0.0   5.395833  1.850000   no  12  겨울  8.5
# 362  2020-12-28      1.3  46230     0.0   6.920833  1.441667  yes  12  겨울  6.7
# 363  2020-12-29      0.2  35251     0.0   1.033333  2.733333  yes  12  겨울  9.7
# 364  2020-12-30      0.0  22194     0.0 -10.366667  4.037500   no  12  겨울  6.7
# 365  2020-12-31      0.0  24202     0.0  -9.229167  2.529167   no  12  겨울  7.4
#
# [366 rows x 10 columns]

# %%
data_fin.corr()
# Out:
#           강수량(mm)      이용건수    적설(cm)    기온(°C)   풍속(m/s)       일교차
# 강수량(mm)  1.000000 -0.304282 -0.014740  0.231571  0.248152 -0.345336
# 이용건수    -0.304282  1.000000 -0.204059  0.616661 -0.166312  0.334215
# 적설(cm)  -0.014740 -0.204059  1.000000 -0.256155  0.146340 -0.061480
# 기온(°C)   0.231571  0.616661 -0.256155  1.000000 -0.038333 -0.130605
# 풍속(m/s)  0.248152 -0.166312  0.146340 -0.038333  1.000000 -0.237154
# 일교차     -0.345336  0.334215 -0.061480 -0.130605 -0.237154  1.000000

# %%
m=[str(i).split(' ')[0] for i in pd.date_range(start='2020-01-01',periods=12,freq='MS')]
m
# Out:
# ['2020-01-01',
#  '2020-02-01',
#  '2020-03-01',
#  '2020-04-01',
#  '2020-05-01',
#  '2020-06-01',
#  '2020-07-01',
#  '2020-08-01',
#  '2020-09-01',
#  '2020-10-01',
#  '2020-11-01',
#  '2020-12-01']

# %%
data_fin.to_csv('data/data_fin.csv')

# %%
pd.read_csv('data/data_fin.csv',index_col=0)
# Out:
#            대여일자  강수량(mm)   이용건수  적설(cm)     기온(°C)   풍속(m/s) 우천여부   월  계절  일교차
# 0    2020-01-01      0.1  15799     0.0  -2.708333  1.104167  yes   1  겨울  6.8
# 1    2020-01-02      0.0  28418     0.0   0.987500  1.912500   no   1  겨울  4.5
# 2    2020-01-03      0.0  30318     0.0   0.120833  1.879167   no   1  겨울  7.6
# 3    2020-01-04      0.0  25061     0.0   1.054167  1.895833   no   1  겨울  8.8
# 4    2020-01-05      0.0  22504     0.0   1.175000  1.045833   no   1  겨울  9.6
# ..          ...      ...    ...     ...        ...       ...  ...  ..  ..  ...
# 361  2020-12-27      0.0  36352     0.0   5.395833  1.850000   no  12  겨울  8.5
# 362  2020-12-28      1.3  46230     0.0   6.920833  1.441667  yes  12  겨울  6.7
# 363  2020-12-29      0.2  35251     0.0   1.033333  2.733333  yes  12  겨울  9.7
# 364  2020-12-30      0.0  22194     0.0 -10.366667  4.037500   no  12  겨울  6.7
# 365  2020-12-31      0.0  24202     0.0  -9.229167  2.529167   no  12  겨울  7.4
#
# [366 rows x 10 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(data_fin['대여일자'],data_fin['이용건수'])
plt.xticks(m, 
           labels=['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월','11월','12월'])
# Out:
# ([<matplotlib.axis.XTick at 0x20792001a90>,
# ...
#  [Text(0.0, 0, '1월'),
#   Text(31.0, 0, '2월'),
#   Text(60.0, 0, '3월'),
#   Text(91.0, 0, '4월'),
#   Text(121.0, 0, '5월'),
#   Text(152.0, 0, '6월'),
#   Text(182.0, 0, '7월'),
#   Text(213.0, 0, '8월'),
#   Text(244.0, 0, '9월'),
#   Text(274.0, 0, '10월'),
#   Text(305.0, 0, '11월'),
#   Text(335.0, 0, '12월')])

# %%
plt.figure(figsize=(20,10))
plt.plot(data_fin['대여일자'],data_fin['일교차'])
plt.xticks(m, 
           labels=['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월','11월','12월'])
# Out:
# ([<matplotlib.axis.XTick at 0x2079205a0a0>,
# ...
#  [Text(0.0, 0, '1월'),
#   Text(31.0, 0, '2월'),
#   Text(60.0, 0, '3월'),
#   Text(91.0, 0, '4월'),
#   Text(121.0, 0, '5월'),
#   Text(152.0, 0, '6월'),
#   Text(182.0, 0, '7월'),
#   Text(213.0, 0, '8월'),
#   Text(244.0, 0, '9월'),
#   Text(274.0, 0, '10월'),
#   Text(305.0, 0, '11월'),
#   Text(335.0, 0, '12월')])

# %%
plt.figure(figsize=(20,10))
plt.plot(data_fin['대여일자'],data_fin['기온(°C)'])
plt.xticks(m, 
           labels=['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월','11월','12월'])
# Out:
# ([<matplotlib.axis.XTick at 0x1d823ad1eb0>,
# ...
#  [Text(0.0, 0, '1월'),
#   Text(31.0, 0, '2월'),
#   Text(60.0, 0, '3월'),
#   Text(91.0, 0, '4월'),
#   Text(121.0, 0, '5월'),
#   Text(152.0, 0, '6월'),
#   Text(182.0, 0, '7월'),
#   Text(213.0, 0, '8월'),
#   Text(244.0, 0, '9월'),
#   Text(274.0, 0, '10월'),
#   Text(305.0, 0, '11월'),
#   Text(335.0, 0, '12월')])

# %%
ex_1=data_fin[data_fin['강수량(mm)']!=0]
ex_1
ex_2=data_fin[data_fin['강수량(mm)']==0]
ex_2
# Out:
#            대여일자  강수량(mm)   이용건수  적설(cm)    기온(°C)   풍속(m/s) 우천여부   월  계절  일교차
# 0    2020-01-01      0.1  15799     0.0 -2.708333  1.104167  yes  01  겨울  6.8
# 5    2020-01-06      1.2  15160     0.0  2.725000  3.100000  yes  01  겨울  3.8
# 6    2020-01-07     39.8   1884     0.0  6.062500  4.183333  yes  01  겨울  3.3
# 7    2020-01-08     18.7  21186     0.0  3.137500  3.345833  yes  01  겨울  9.0
# 18   2020-01-19      0.6  17224     0.3  1.816667  2.104167  yes  01  겨울  5.2
# ..          ...      ...    ...     ...       ...       ...  ...  ..  ..  ...
# 326  2020-11-22      5.0  34182     0.0  6.145833  2.595833  yes  11  가을  7.1
# 347  2020-12-13      2.9  14137    36.5 -0.441667  2.837500  yes  12  겨울  7.6
# 352  2020-12-18      0.2  29787     8.2 -1.625000  2.933333  yes  12  겨울  7.1
# 362  2020-12-28      1.3  46230     0.0  6.920833  1.441667  yes  12  겨울  6.7
# 363  2020-12-29      0.2  35251     0.0  1.033333  2.733333  yes  12  겨울  9.7
#
# [105 rows x 10 columns]
# ...

# %%
ex_1.corr()
ex_2.corr()
# Out:
#           강수량(mm)      이용건수    적설(cm)    기온(°C)   풍속(m/s)       일교차
# 강수량(mm)  1.000000 -0.371789 -0.075929  0.259663  0.230932 -0.261221
# 이용건수    -0.371789  1.000000 -0.218465  0.459431 -0.120106  0.288471
# 적설(cm)  -0.075929 -0.218465  1.000000 -0.401443  0.163045  0.047106
# 기온(°C)   0.259663  0.459431 -0.401443  1.000000 -0.201671 -0.269738
# 풍속(m/s)  0.230932 -0.120106  0.163045 -0.201671  1.000000  0.070739
# 일교차     -0.261221  0.288471  0.047106 -0.269738  0.070739  1.000000
#          강수량(mm)      이용건수    적설(cm)    기온(°C)   풍속(m/s)       일교차
# 강수량(mm)      NaN       NaN       NaN       NaN       NaN       NaN
# 이용건수         NaN  1.000000 -0.205857  0.849590 -0.086617  0.209205
# 적설(cm)       NaN -0.205857  1.000000 -0.276090  0.102532 -0.106997
# 기온(°C)       NaN  0.849590 -0.276090  1.000000 -0.077253  0.096325
# 풍속(m/s)      NaN -0.086617  0.102532 -0.077253  1.000000 -0.231270
# 일교차          NaN  0.209205 -0.106997  0.096325 -0.231270  1.000000

# %%
plt.figure(figsize=(20,10))
plt.plot(ex_1['대여일자'],ex_1['강수량(mm)'])
# plt.xticks(m, 
#            labels=['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월','11월','12월'])

# %%
data_fin.loc[:,['이용건수','일교차']].corr()
# Out:
#           이용건수       일교차
# 이용건수  1.000000  0.334215
# 일교차   0.334215  1.000000

# %% [markdown]
# # 계절별 이용건수 비교

# %%
data_fin1=data_fin

# %%
월1=[i.split('-')[1] for i in data_fin1['대여일자']]

s1=[]
for i in 월:
    if i=='02' or i=='03' or i=='04':
        s1.append('봄')
    elif i=='05' or i=='06' or i=='07':
        s1.append('여름')
    
    elif i=='08' or i=='09' or i=='10':
        s1.append('가을')
    else:
        s1.append('겨울')

# %%
data_fin1['계절']=s1

# %%
sns.boxplot(x=data_fin1['계절'],y=data_fin1['이용건수'])
# Out:
# <AxesSubplot:xlabel='계절', ylabel='이용건수'>

# %%
# *
월=[i.split('-')[1] for i in data_fin['대여일자']]

s=[]
for i in 월:
    if i=='03' or i=='04' or i=='05':
        s.append('봄')
    elif i=='06' or i=='07' or i=='08':
        s.append('여름')
    
    elif i=='09' or i=='10' or i=='11':
        s.append('가을')
    else:
        s.append('겨울')


data_fin['계절']=s
data_fin
# Out:
#            대여일자  강수량(mm)   이용건수  적설(cm)     기온(°C)   풍속(m/s) 우천여부   월  계절  일교차
# 0    2020-01-01      0.1  15799     0.0  -2.708333  1.104167  yes  01  겨울  6.8
# 1    2020-01-02      0.0  28418     0.0   0.987500  1.912500   no  01  겨울  4.5
# 2    2020-01-03      0.0  30318     0.0   0.120833  1.879167   no  01  겨울  7.6
# 3    2020-01-04      0.0  25061     0.0   1.054167  1.895833   no  01  겨울  8.8
# 4    2020-01-05      0.0  22504     0.0   1.175000  1.045833   no  01  겨울  9.6
# ..          ...      ...    ...     ...        ...       ...  ...  ..  ..  ...
# 361  2020-12-27      0.0  36352     0.0   5.395833  1.850000   no  12  겨울  8.5
# 362  2020-12-28      1.3  46230     0.0   6.920833  1.441667  yes  12  겨울  6.7
# 363  2020-12-29      0.2  35251     0.0   1.033333  2.733333  yes  12  겨울  9.7
# 364  2020-12-30      0.0  22194     0.0 -10.366667  4.037500   no  12  겨울  6.7
# 365  2020-12-31      0.0  24202     0.0  -9.229167  2.529167   no  12  겨울  7.4
#
# [366 rows x 10 columns]

# %%
# *
sns.boxplot(x=data_fin['계절'],y=data_fin['이용건수'])
# Out:
# <AxesSubplot:xlabel='계절', ylabel='이용건수'>

# %%
pd.pivot_table(data_fin,index=['월'],values=['이용건수'],aggfunc=['max','min','sum'])
pd.pivot_table(data_fin,index=['월'],values=['일교차'],aggfunc=['max','min','mean'])
# Out:
#        max    min      sum
#       이용건수   이용건수     이용건수
# 월
# 01   37358   1884   778073
# 02   40158   6656   750132
# 03   72757  10426  1490825
# 04   93481  28609  2108040
# 05  102554   7480  2427680
# 06  108784  19519  2725712
# 07  106341   4800  2542943
# 08   89006  11367  1709519
# 09  116399   3110  2763148
# 10  103921  73544  2840128
# 11   90325  31633  1956810
# 12   54843  14137  1178737
#      max  min       mean
#      일교차  일교차        일교차
# 월
# 01  11.8  2.4   7.251613
# 02  14.5  1.5   8.162069
# 03  14.4  5.0  10.283871
# 04  15.9  3.8   9.926667
# 05  16.2  3.6   9.187097
# 06  13.5  2.9   8.810000
# 07  10.4  2.2   6.574194
# 08   8.4  1.3   4.629032
# 09  11.2  2.7   7.273333
# 10  13.1  4.1   9.464516
# 11  12.7  2.2   8.150000
# 12  11.6  4.5   7.767742

# %%
pd.pivot_table(data_fin,index=['계절'],values=['이용건수'],aggfunc=['sum'])
pd.pivot_table(data_fin,index=['계절'],values=['일교차'],aggfunc=['max','min','mean'])
# Out:
#         sum
#        이용건수
# 계절
# 가을  7560086
# 겨울  2706942
# 봄   6026545
# 여름  6978174
#      max  min      mean
#      일교차  일교차       일교차
# 계절
# 가을  13.1  2.2  8.308791
# 겨울  14.5  1.5  7.717582
# 봄   16.2  3.6  9.797826
# 여름  13.5  1.3  6.647826

# %%
pd.pivot_table(data_fin,index=['월','계절'],values=['강수량(mm)','이용건수'],aggfunc=['mean','sum','max'])
temp=pd.pivot_table(data_fin,index=['월'],values='기온(°C)')
# Out:
#             mean                   sum              max
#          강수량(mm)          이용건수 강수량(mm)     이용건수 강수량(mm)    이용건수
# 월  계절
# 01 겨울   1.951613  25099.129032    60.5   778073    39.8   37358
# 02 겨울   1.831034  25866.620690    53.1   750132    16.6   40158
# 03 봄    0.525806  48091.129032    16.3  1490825    11.8   72757
# 04 봄    0.563333  70268.000000    16.9  2108040    10.3   93481
# 05 봄    3.600000  78312.258065   111.6  2427680    29.8  102554
# 06 여름   4.680000  90857.066667   140.4  2725712    70.3  108784
# 07 여름   8.690323  82030.419355   269.4  2542943   102.6  106341
# 08 여름  21.590323  55145.774194   669.3  1709519   106.8   89006
# 09 가을   6.050000  92104.933333   181.5  2763148    62.9  116399
# 10 가을   0.000000  91617.032258     0.0  2840128     0.0  103921
# 11 가을   4.003333  65227.000000   120.1  1956810    88.8   90325
# 12 겨울   0.148387  38023.774194     4.6  1178737     2.9   54843

# %% [markdown]
# # 월별 이용건수/비온날 비교

# %%
month=[]
for i in data_fin['대여일자']:
    month.append(i.split('-')[1])
data_fin['월']=month
data_fin
# Out:
#            대여일자  강수량(mm)   이용건수  적설(cm)     기온(°C)   풍속(m/s) 우천여부   월  계절  일교차
# 0    2020-01-01      0.1  15799     0.0  -2.708333  1.104167  yes  01  겨울  6.8
# 1    2020-01-02      0.0  28418     0.0   0.987500  1.912500   no  01  겨울  4.5
# 2    2020-01-03      0.0  30318     0.0   0.120833  1.879167   no  01  겨울  7.6
# 3    2020-01-04      0.0  25061     0.0   1.054167  1.895833   no  01  겨울  8.8
# 4    2020-01-05      0.0  22504     0.0   1.175000  1.045833   no  01  겨울  9.6
# ..          ...      ...    ...     ...        ...       ...  ...  ..  ..  ...
# 361  2020-12-27      0.0  36352     0.0   5.395833  1.850000   no  12  겨울  8.5
# 362  2020-12-28      1.3  46230     0.0   6.920833  1.441667  yes  12  겨울  6.7
# 363  2020-12-29      0.2  35251     0.0   1.033333  2.733333  yes  12  겨울  9.7
# 364  2020-12-30      0.0  22194     0.0 -10.366667  4.037500   no  12  겨울  6.7
# 365  2020-12-31      0.0  24202     0.0  -9.229167  2.529167   no  12  겨울  7.4
#
# [366 rows x 10 columns]

# %%
data_fin[data_fin['월']=='10']
# Out:
#            대여일자  강수량(mm)    이용건수  적설(cm)     기온(°C)   풍속(m/s) 우천여부  계절   월
# 274  2020-10-01      0.0   79876     0.0  18.729167  2.158333   no  가을  10
# 275  2020-10-02      0.0   73544     0.0  18.966667  2.100000   no  가을  10
# 276  2020-10-03      0.0   95369     0.0  20.020833  1.704167   no  가을  10
# 277  2020-10-04      0.0   84318     0.0  17.366667  2.891667   no  가을  10
# 278  2020-10-05      0.0   91830     0.0  13.195833  2.562500   no  가을  10
# 279  2020-10-06      0.0   98944     0.0  14.062500  1.962500   no  가을  10
# 280  2020-10-07      0.0  101878     0.0  15.862500  2.008333   no  가을  10
# 281  2020-10-08      0.0  103921     0.0  17.237500  3.112500   no  가을  10
# 282  2020-10-09      0.0  101875     0.0  17.150000  2.820833   no  가을  10
# 283  2020-10-10      0.0  102432     0.0  16.729167  2.054167   no  가을  10
# 284  2020-10-11      0.0   93534     0.0  16.862500  1.837500   no  가을  10
# ...

# %%
sum=pd.pivot_table(data_fin,index='월',values='이용건수',aggfunc='sum')
sum
pd.concat([sum,temp],axis=1)
# Out:
#        이용건수
# 월
# 01   778073
# 02   750132
# 03  1490825
# 04  2108040
# 05  2427680
# 06  2725712
# 07  2542943
# 08  1709519
# 09  2763148
# 10  2840128
# 11  1956810
# 12  1178737
#        이용건수     기온(°C)
# 월
# 01   778073   1.627554
# 02   750132   2.525431
# 03  1490825   7.669624
# 04  2108040  11.084028
# 05  2427680  18.006452
# 06  2725712  23.879861
# 07  2542943  24.134677
# 08  1709519  26.535818
# 09  2763148  21.403611
# 10  2840128  14.300672
# 11  1956810   8.067639
# 12  1178737  -0.300806

# %%
rain=data_fin[data_fin['우천여부']=='yes']
rain2=pd.pivot_table(rain,index=['월'],values=['우천여부'],aggfunc='count')
rain2
# Out:
#     우천여부
# 월
# 01     6
# 02    10
# 03     5
# 04     3
# 05    12
# 06    13
# 07    15
# 08    18
# 09    12
# 11     7
# 12     4
# <AxesSubplot:xlabel='월'>
# <AxesSubplot:xlabel='월'>

# %%
# *
pd.concat([sum,temp,rain2],axis=1)
# Out:
#        이용건수     기온(°C)  우천여부
# 월
# 01   778073   1.627554   6.0
# 02   750132   2.525431  10.0
# 03  1490825   7.669624   5.0
# 04  2108040  11.084028   3.0
# 05  2427680  18.006452  12.0
# 06  2725712  23.879861  13.0
# 07  2542943  24.134677  15.0
# 08  1709519  26.535818  18.0
# 09  2763148  21.403611  12.0
# 10  2840128  14.300672   NaN
# 11  1956810   8.067639   7.0
# 12  1178737  -0.300806   4.0

# %%
temp=pd.pivot_table(data_fin,index=['월'],values=['기온(°C)'])
temp
# Out:
#        기온(°C)
# 월
# 01   1.627554
# 02   2.525431
# 03   7.669624
# 04  11.084028
# 05  18.006452
# 06  23.879861
# 07  24.134677
# 08  26.535818
# 09  21.403611
# 10  14.300672
# 11   8.067639
# 12  -0.300806

# %%
data_fin[data_fin['월']=='01']
data_fin[data_fin['월']=='09']
# Out:
#           대여일자  강수량(mm)   이용건수  적설(cm)    기온(°C)   풍속(m/s) 우천여부   월  계절   일교차
# 0   2020-01-01      0.1  15799     0.0 -2.708333  1.104167  yes  01  겨울   6.8
# 1   2020-01-02      0.0  28418     0.0  0.987500  1.912500   no  01  겨울   4.5
# 2   2020-01-03      0.0  30318     0.0  0.120833  1.879167   no  01  겨울   7.6
# 3   2020-01-04      0.0  25061     0.0  1.054167  1.895833   no  01  겨울   8.8
# 4   2020-01-05      0.0  22504     0.0  1.175000  1.045833   no  01  겨울   9.6
# 5   2020-01-06      1.2  15160     0.0  2.725000  3.100000  yes  01  겨울   3.8
# 6   2020-01-07     39.8   1884     0.0  6.062500  4.183333  yes  01  겨울   3.3
# 7   2020-01-08     18.7  21186     0.0  3.137500  3.345833  yes  01  겨울   9.0
# 8   2020-01-09      0.0  28258     0.0 -0.900000  2.250000   no  01  겨울   4.5
# 9   2020-01-10      0.0  28891     0.0 -0.816667  1.566667   no  01  겨울   8.1
# 10  2020-01-11      0.0  22675     0.0 -0.033333  1.833333   no  01  겨울   6.1
# ...

# %%
df=data_fin[data_fin['강수량(mm)']!=0]
# Out:
#            대여일자  강수량(mm)   이용건수  적설(cm)    기온(°C)   풍속(m/s) 우천여부   월  계절  일교차
# 0    2020-01-01      0.1  15799     0.0 -2.708333  1.104167  yes  01  겨울  6.8
# 5    2020-01-06      1.2  15160     0.0  2.725000  3.100000  yes  01  겨울  3.8
# 6    2020-01-07     39.8   1884     0.0  6.062500  4.183333  yes  01  겨울  3.3
# 7    2020-01-08     18.7  21186     0.0  3.137500  3.345833  yes  01  겨울  9.0
# 18   2020-01-19      0.6  17224     0.3  1.816667  2.104167  yes  01  겨울  5.2
# ..          ...      ...    ...     ...       ...       ...  ...  ..  ..  ...
# 326  2020-11-22      5.0  34182     0.0  6.145833  2.595833  yes  11  가을  7.1
# 347  2020-12-13      2.9  14137    36.5 -0.441667  2.837500  yes  12  겨울  7.6
# 352  2020-12-18      0.2  29787     8.2 -1.625000  2.933333  yes  12  겨울  7.1
# 362  2020-12-28      1.3  46230     0.0  6.920833  1.441667  yes  12  겨울  6.7
# 363  2020-12-29      0.2  35251     0.0  1.033333  2.733333  yes  12  겨울  9.7
#
# [105 rows x 10 columns]

# %%
df.to_csv('data/df.csv')

# %%
df
# Out:
#            대여일자  강수량(mm)   이용건수  적설(cm)    기온(°C)   풍속(m/s) 우천여부   월  계절  일교차
# 0    2020-01-01      0.1  15799     0.0 -2.708333  1.104167  yes  01  겨울  6.8
# 5    2020-01-06      1.2  15160     0.0  2.725000  3.100000  yes  01  겨울  3.8
# 6    2020-01-07     39.8   1884     0.0  6.062500  4.183333  yes  01  겨울  3.3
# 7    2020-01-08     18.7  21186     0.0  3.137500  3.345833  yes  01  겨울  9.0
# 18   2020-01-19      0.6  17224     0.3  1.816667  2.104167  yes  01  겨울  5.2
# ..          ...      ...    ...     ...       ...       ...  ...  ..  ..  ...
# 326  2020-11-22      5.0  34182     0.0  6.145833  2.595833  yes  11  가을  7.1
# 347  2020-12-13      2.9  14137    36.5 -0.441667  2.837500  yes  12  겨울  7.6
# 352  2020-12-18      0.2  29787     8.2 -1.625000  2.933333  yes  12  겨울  7.1
# 362  2020-12-28      1.3  46230     0.0  6.920833  1.441667  yes  12  겨울  6.7
# 363  2020-12-29      0.2  35251     0.0  1.033333  2.733333  yes  12  겨울  9.7
#
# [105 rows x 10 columns]

# %%
df2=pd.pivot_table(df,index=['월','대여일자'],values=['강수량(mm)','이용건수'])
df2
# Out:
#                강수량(mm)   이용건수
# 월  대여일자
# 01 2020-01-01      0.1  15799
#    2020-01-06      1.2  15160
#    2020-01-07     39.8   1884
#    2020-01-08     18.7  21186
#    2020-01-19      0.6  17224
# ...                ...    ...
# 11 2020-11-22      5.0  34182
# 12 2020-12-13      2.9  14137
#    2020-12-18      0.2  29787
#    2020-12-28      1.3  46230
#    2020-12-29      0.2  35251
#
# [105 rows x 2 columns]

# %%
df2.loc['01']
# Out:
#             강수량(mm)   이용건수
# 대여일자
# 2020-01-01      0.1  15799
# 2020-01-06      1.2  15160
# 2020-01-07     39.8   1884
# 2020-01-08     18.7  21186
# 2020-01-19      0.6  17224
# 2020-01-28      0.1  31521

# %%
wt=[]
for i in range(1,13):
    if i<10:
        wt.appenddf2.loc['0'+str(i)]
    elif i>=11:
        df2.loc[str(i)]
# Out:
#             강수량(mm)   이용건수
# 대여일자
# 2020-01-01      0.1  15799
# 2020-01-06      1.2  15160
# 2020-01-07     39.8   1884
# 2020-01-08     18.7  21186
# 2020-01-19      0.6  17224
# 2020-01-28      0.1  31521
#             강수량(mm)   이용건수
# 대여일자
# 2020-02-04      1.7  22678
# 2020-02-12      6.7  10527
# 2020-02-15      0.3  28793
# 2020-02-16     15.1   6656
# 2020-02-17      1.0  13589
# 2020-02-21      0.6  29231
# 2020-02-22      6.7  17868
# 2020-02-25     16.6  15599
# 2020-02-28      3.5  12433
# 2020-02-29      0.9  34262
#             강수량(mm)   이용건수
# 대여일자
# 2020-03-02      0.2  35795
# 2020-03-10     11.8  10426
# 2020-03-13      0.5  42672
# 2020-03-26      0.2  46597
# 2020-03-27      3.6  58730
#             강수량(mm)   이용건수
# 대여일자
# 2020-04-17      6.5  35064
# 2020-04-19     10.3  28609
# 2020-04-20      0.1  55326
#             강수량(mm)   이용건수
# 대여일자
# 2020-05-08      2.0  62464
# 2020-05-09     24.4   7480
# 2020-05-10      1.6  64304
# 2020-05-11      0.1  74851
# ...

# %%
df1=pd.pivot_table(df,index=['대여일자'],values=['강수량(mm)','이용건수']).reset_index()
df1
# Out:
#            대여일자  강수량(mm)   이용건수
# 0    2020-01-01      0.1  15799
# 1    2020-01-06      1.2  15160
# 2    2020-01-07     39.8   1884
# 3    2020-01-08     18.7  21186
# 4    2020-01-19      0.6  17224
# ..          ...      ...    ...
# 100  2020-11-22      5.0  34182
# 101  2020-12-13      2.9  14137
# 102  2020-12-18      0.2  29787
# 103  2020-12-28      1.3  46230
# 104  2020-12-29      0.2  35251
#
# [105 rows x 3 columns]

# %%
dt_1=data_1[data_1['우천여부']=='yes']
dt_2=pd.pivot_table(dt_1,index='대여일자',values='우천여부',aggfunc='count').reset_index()
#['일일강수시간']

# %%
dt_2.우천여부
# Out:
# 0      1
# 1      3
# 2      8
# 3      4
# 4      1
#       ..
# 100    4
# 101    4
# 102    1
# 103    1
# 104    1
# Name: 우천여부, Length: 105, dtype: int64

# %%
df1['일일강수시간']=dt_2.우천여부

# %%
df1
# Out:
#            대여일자  강수량(mm)   이용건수  일일강수시간
# 0    2020-01-01      0.1  15799       1
# 1    2020-01-06      1.2  15160       3
# 2    2020-01-07     39.8   1884       8
# 3    2020-01-08     18.7  21186       4
# 4    2020-01-19      0.6  17224       1
# ..          ...      ...    ...     ...
# 100  2020-11-22      5.0  34182       4
# 101  2020-12-13      2.9  14137       4
# 102  2020-12-18      0.2  29787       1
# 103  2020-12-28      1.3  46230       1
# 104  2020-12-29      0.2  35251       1
#
# [105 rows x 4 columns]

# %%
plt.plot(df1.대여일자,df1.일일강수시간)

# %%
df1.corr()
# Out:
#           강수량(mm)      이용건수    일일강수시간
# 강수량(mm)  1.000000 -0.371789  0.669391
# 이용건수    -0.371789  1.000000 -0.480405
# 일일강수시간   0.669391 -0.480405  1.000000

# %%
# 일일 강수지속시간이 많으면서 이용건수가 많은날은 없음
sns.scatterplot(x=df1['이용건수'],y=df1['일일강수시간'])
sns.lmplot(x='이용건수',y='일일강수시간',data=df1)
# Out:
# <AxesSubplot:xlabel='이용건수', ylabel='일일강수시간'>

# %%
# Out:
#           강수량(mm)      이용건수    일일강수시간
# 강수량(mm)  1.000000 -0.371789  0.669391
# 이용건수    -0.371789  1.000000 -0.480405
# 일일강수시간   0.669391 -0.480405  1.000000

# %%
plt.plot(df1['대여일자'],df1['이용건수'])

# %%
# plt.plot(df1['대여일자'],df1['강수량(mm)'])
# plt.plot(df1['대여일자'],df1['이용건수'])
plt.plot(df1['대여일자'],df1['일일강수시간'])

# %%
c=pd.pivot_table(df1,index='일일강수시간',values='이용건수').reset_index()
c
# Out:
#     일일강수시간          이용건수
# 0        1  59105.590909
# 1        2  70427.000000
# 2        3  63360.166667
# 3        4  46035.222222
# 4        5  33330.333333
# 5        6  46596.250000
# 6        7  49908.333333
# 7        8  32750.500000
# 8        9  84338.000000
# 9       10  49896.500000
# 10      11  42454.571429
# 11      12  58153.000000
# 12      13  37620.000000
# 13      14  25943.000000
# 14      15  17369.000000
# 15      16  16541.500000
# 16      17  13526.000000
# 17      18  12252.000000
# 18      19  10964.500000
# 19      21   7480.000000
# 20      22   4800.000000
# 21      23   3110.000000

# %%
sns.barplot(data=c,x='일일강수시간',y='이용건수')
# Out:
# <AxesSubplot:xlabel='일일강수시간', ylabel='이용건수'>

# %% [markdown]
# # 08/22 저녁

# %%
data_2=data_1[data_1['강수량(mm)']!=0]

# %%
plt.scatter(data_2['강수량(mm)'],data_2['이용건수'])

# %%
data_3=data_2[data_2['강수량(mm)']<=1]

# %%
data_3.corr()
plt.scatter(data_3['강수량(mm)'],data_3['이용건수'])
# Out:
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)    적설(cm)
# 이용건수     1.000000  0.224686 -0.288570 -0.058721 -0.065076
# 기온(°C)   0.224686  1.000000 -0.002897 -0.227326 -0.437083
# 강수량(mm) -0.288570 -0.002897  1.000000  0.216452  0.076322
# 풍속(m/s) -0.058721 -0.227326  0.216452  1.000000  0.140937
# 적설(cm)  -0.065076 -0.437083  0.076322  0.140937  1.000000

# %%
data_4=data_2[(data_2['강수량(mm)']>1)&(data_2['강수량(mm)']<=3)]
data_4.corr()
plt.scatter(data_4['강수량(mm)'],data_4['이용건수'])
# Out:
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)    적설(cm)
# 이용건수     1.000000  0.181401 -0.133305 -0.133388 -0.021385
# 기온(°C)   0.181401  1.000000  0.136341 -0.129391 -0.295266
# 강수량(mm) -0.133305  0.136341  1.000000  0.087215 -0.036303
# 풍속(m/s) -0.133388 -0.129391  0.087215  1.000000 -0.023476
# 적설(cm)  -0.021385 -0.295266 -0.036303 -0.023476  1.000000

# %%
data_5=data_2[(data_2['강수량(mm)']>3)&(data_2['강수량(mm)']<=5)]
max(data_5['강수량(mm)']),min(data_5['강수량(mm)'])
data_5.corr()
plt.scatter(data_5['강수량(mm)'],data_5['이용건수'])
# Out:
# (5.0, 3.1)
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)    적설(cm)
# 이용건수     1.000000  0.101374 -0.018792 -0.174750 -0.067637
# 기온(°C)   0.101374  1.000000  0.456434 -0.258642 -0.382783
# 강수량(mm) -0.018792  0.456434  1.000000  0.023191 -0.111749
# 풍속(m/s) -0.174750 -0.258642  0.023191  1.000000  0.034816
# 적설(cm)  -0.067637 -0.382783 -0.111749  0.034816  1.000000

# %%
data_6=data_2[(data_2['강수량(mm)']>5)&(data_2['강수량(mm)']<=10)]
max(data_6['강수량(mm)']),min(data_6['강수량(mm)'])
data_6.corr()
plt.scatter(data_6['강수량(mm)'],data_6['이용건수'])
# Out:
# (9.8, 5.1)
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)  적설(cm)
# 이용건수     1.000000  0.310951 -0.189600 -0.346051     NaN
# 기온(°C)   0.310951  1.000000 -0.068331 -0.286031     NaN
# 강수량(mm) -0.189600 -0.068331  1.000000  0.299207     NaN
# 풍속(m/s) -0.346051 -0.286031  0.299207  1.000000     NaN
# 적설(cm)        NaN       NaN       NaN       NaN     NaN

# %%
data_7=data_2[(data_2['강수량(mm)']>10)&(data_2['강수량(mm)']<=15)]
max(data_7['강수량(mm)']),min(data_7['강수량(mm)'])
data_7.corr()
plt.scatter(data_7['강수량(mm)'],data_7['이용건수'])
# Out:
# (14.6, 10.4)
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)  적설(cm)
# 이용건수     1.000000  0.383259 -0.137532 -0.515064     NaN
# 기온(°C)   0.383259  1.000000  0.188510 -0.392434     NaN
# 강수량(mm) -0.137532  0.188510  1.000000 -0.287056     NaN
# 풍속(m/s) -0.515064 -0.392434 -0.287056  1.000000     NaN
# 적설(cm)        NaN       NaN       NaN       NaN     NaN

# %%
data_8=data_2[(data_2['강수량(mm)']>15)&(data_2['강수량(mm)']<=20)]
max(data_8['강수량(mm)']),min(data_6['강수량(mm)'])
data_8.corr()
# Out:
# (19.8, 5.1)
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)  적설(cm)
# 이용건수     1.000000  0.298851  0.172012 -0.639850     NaN
# 기온(°C)   0.298851  1.000000  0.014839 -0.372143     NaN
# 강수량(mm)  0.172012  0.014839  1.000000 -0.524895     NaN
# 풍속(m/s) -0.639850 -0.372143 -0.524895  1.000000     NaN
# 적설(cm)        NaN       NaN       NaN       NaN     NaN

# %%
data_9=data_2[(data_2['강수량(mm)']>20)&(data_2['강수량(mm)']<=25)]
max(data_9['강수량(mm)']),min(data_6['강수량(mm)'])
data_9.corr()
# Out:
# (22.8, 5.1)
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)  적설(cm)
# 이용건수     1.000000 -0.119455 -0.008347  0.550020     NaN
# 기온(°C)  -0.119455  1.000000  0.620589  0.206454     NaN
# 강수량(mm) -0.008347  0.620589  1.000000  0.774089     NaN
# 풍속(m/s)  0.550020  0.206454  0.774089  1.000000     NaN
# 적설(cm)        NaN       NaN       NaN       NaN     NaN

# %%
data_1

# %%
ra=data_1['강수량(mm)']
bins=[0,1,3,5,10,20,30,50]
labels=['1','2','3','4','5','6','7']
cut=pd.cut(ra,bins=bins,labels=labels,right=False)
#pd.cut(data,bins,labels=labels)
data_1['비수준']=cut
data_1
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 비수준   월  계절  \
# 0     2020-01-01   00   599    -6.5      0.0      0.0     0.0   1  01  겨울
# 1     2020-01-01   01   847    -5.9      0.0      1.7     0.0   1  01  겨울
# 2     2020-01-01   02   748    -5.7      0.0      0.1     0.0   1  01  겨울
# 3     2020-01-01   03   472    -5.6      0.0      0.0     0.0   1  01  겨울
# 4     2020-01-01   04   344    -5.4      0.0      0.0     0.0   1  01  겨울
# ...          ...  ...   ...     ...      ...      ...     ...  ..  ..  ..
# 8760  2020-12-31   19  1340    -7.1      0.0      2.4     0.0   1  12  겨울
# 8761  2020-12-31   20  1062    -7.1      0.0      3.2     0.0   1  12  겨울
# 8762  2020-12-31   21   900    -7.2      0.0      2.7     0.0   1  12  겨울
# 8763  2020-12-31   22   537    -7.4      0.0      2.5     0.0   1  12  겨울
# 8764  2020-12-31   23   459    -7.6      0.0      2.2     0.0   1  12  겨울
#
#       전시간대비     시간대
# 0         0  출/퇴근 외
# 1       248  출/퇴근 외
# ...

# %%
data_2=data_1[data_1['비수준']!='1']
data_2
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 비수준   월  계절  \
# 147   2020-01-07   03    44     4.6      2.1      4.5     0.0   2  01  겨울
# 150   2020-01-07   06    32     5.5      7.4      3.3     0.0   4  01  겨울
# 153   2020-01-07   09   116     5.8      6.5      3.6     0.0   4  01  겨울
# 156   2020-01-07   12    36     6.4      2.4      4.3     0.0   2  01  겨울
# 159   2020-01-07   15    57     6.5      4.6      4.0     0.0   3  01  겨울
# ...          ...  ...   ...     ...      ...      ...     ...  ..  ..  ..
# 7808  2020-11-22   03   156     8.1      1.3      1.4     0.0   2  11  가을
# 7811  2020-11-22   06    44     6.5      1.5      2.5     0.0   2  11  가을
# 7814  2020-11-22   09   515     5.1      2.0      2.7     0.0   2  11  가을
# 8318  2020-12-13   09   215    -0.2      1.7      1.9     3.0   2  12  겨울
# 8672  2020-12-28   03   127     5.6      1.3      0.7     0.0   2  12  겨울
#
#       전시간대비     시간대
# 147     -52  출/퇴근 외
# 150       8  출/퇴근 외
# ...

# %%
data_1[data_1['비수준']=='7']
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 비수준   월  계절  \
# 7739  2020-11-19   06    36    18.8     42.1      4.1     0.0   7  11  가을
# 7742  2020-11-19   09   176    18.5     36.8      4.1     0.0   7  11  가을
#
#       전시간대비     시간대
# 7739     17  출/퇴근 외
# 7742     51    출/퇴근

# %%
sns.boxplot(data_2['비수준'],data_2['이용건수'],data=data_2[data_2['비수준']!='1'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='비수준', ylabel='이용건수'>

# %%
data

# %%
data_1
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm)     시간대  계절   월
# 0     2020-01-01   00   599    -6.5      0.0      0.0     NaN  출/퇴근 외  겨울  01
# 1     2020-01-01   01   847    -5.9      NaN      1.7     NaN  출/퇴근 외  겨울  01
# 2     2020-01-01   02   748    -5.7      NaN      0.1     NaN  출/퇴근 외  겨울  01
# 3     2020-01-01   03   472    -5.6      0.0      0.0     NaN  출/퇴근 외  겨울  01
# 4     2020-01-01   04   344    -5.4      NaN      0.0     NaN  출/퇴근 외  겨울  01
# ...          ...  ...   ...     ...      ...      ...     ...     ...  ..  ..
# 8760  2020-12-31   19  1340    -7.1      NaN      2.4     NaN    출/퇴근  겨울  12
# 8761  2020-12-31   20  1062    -7.1      NaN      3.2     NaN  출/퇴근 외  겨울  12
# 8762  2020-12-31   21   900    -7.2      NaN      2.7     NaN  출/퇴근 외  겨울  12
# 8763  2020-12-31   22   537    -7.4      NaN      2.5     NaN  출/퇴근 외  겨울  12
# 8764  2020-12-31   23   459    -7.6      NaN      2.2     NaN  출/퇴근 외  겨울  12
#
# [8765 rows x 10 columns]

# %%
ra=data_1['강수량(mm)']
bins=[0,1,3,5,10,20,30,50]
labels=['1','2','3','4','5','6','7']
cut=pd.cut(ra,bins=bins,labels=labels,right=False)
#pd.cut(data,bins,labels=labels)
data_1['비수준']=cut
data_1
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 비수준
# 0     2020-01-01   00   599    -6.5      0.0      0.0     0.0   1
# 1     2020-01-01   01   847    -5.9      0.0      1.7     0.0   1
# 2     2020-01-01   02   748    -5.7      0.0      0.1     0.0   1
# 3     2020-01-01   03   472    -5.6      0.0      0.0     0.0   1
# 4     2020-01-01   04   344    -5.4      0.0      0.0     0.0   1
# ...          ...  ...   ...     ...      ...      ...     ...  ..
# 8760  2020-12-31   19  1340    -7.1      0.0      2.4     0.0   1
# 8761  2020-12-31   20  1062    -7.1      0.0      3.2     0.0   1
# 8762  2020-12-31   21   900    -7.2      0.0      2.7     0.0   1
# 8763  2020-12-31   22   537    -7.4      0.0      2.5     0.0   1
# 8764  2020-12-31   23   459    -7.6      0.0      2.2     0.0   1
#
# [8765 rows x 8 columns]

# %%
sns.boxplot(data_1['비수준'],data_1['이용건수'],data=data_1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='비수준', ylabel='이용건수'>

# %%
ra=data_1['강수량(mm)']
bins=[0,1,3,5,10,20,30,50]
labels=['1','2','3','4','5','6','7']
cut=pd.cut(ra,bins=bins,labels=labels,right=False)
#pd.cut(data,bins,labels=labels)
data_1['비수준']=cut
data_1

# %%
sns.boxplot(data_3['비수준'],data_3['이용건수'],data=data_3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='비수준', ylabel='이용건수'>

# %%
data_3=data_1[(data_1['계절']=='여름')]

# %%
data_1[(data_1['계절']=='여름')].corr()
# & (data_1['강수량(mm)']!=0)
# Out:
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)  적설(cm)
# 이용건수     1.000000  0.352716 -0.246798  0.150811     NaN
# 기온(°C)   0.352716  1.000000 -0.112864  0.138099     NaN
# 강수량(mm) -0.246798 -0.112864  1.000000  0.172656     NaN
# 풍속(m/s)  0.150811  0.138099  0.172656  1.000000     NaN
# 적설(cm)        NaN       NaN       NaN       NaN     NaN

# %%
sns.boxplot(data_1['비수준'],data_1['이용건수'],data=data_1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='비수준', ylabel='이용건수'>

# %%
ra=data_1['강수량(mm)']
bins=[0,1,5,50]
labels=['1','2','3']
cut=pd.cut(ra,bins=bins,labels=labels,right=False)
#pd.cut(data,bins,labels=labels)
data_1['비수준']=cut
data_1
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 비수준   월  계절
# 0     2020-01-01   00   599    -6.5      0.0      0.0     0.0   1  01  겨울
# 1     2020-01-01   01   847    -5.9      0.0      1.7     0.0   1  01  겨울
# 2     2020-01-01   02   748    -5.7      0.0      0.1     0.0   1  01  겨울
# 3     2020-01-01   03   472    -5.6      0.0      0.0     0.0   1  01  겨울
# 4     2020-01-01   04   344    -5.4      0.0      0.0     0.0   1  01  겨울
# ...          ...  ...   ...     ...      ...      ...     ...  ..  ..  ..
# 8760  2020-12-31   19  1340    -7.1      0.0      2.4     0.0   1  12  겨울
# 8761  2020-12-31   20  1062    -7.1      0.0      3.2     0.0   1  12  겨울
# 8762  2020-12-31   21   900    -7.2      0.0      2.7     0.0   1  12  겨울
# 8763  2020-12-31   22   537    -7.4      0.0      2.5     0.0   1  12  겨울
# 8764  2020-12-31   23   459    -7.6      0.0      2.2     0.0   1  12  겨울
#
# [8765 rows x 10 columns]

# %%
data_1
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 비수준   월  계절
# 0     2020-01-01   00   599    -6.5      0.0      0.0     0.0   1  01  겨울
# 1     2020-01-01   01   847    -5.9      0.0      1.7     0.0   1  01  겨울
# 2     2020-01-01   02   748    -5.7      0.0      0.1     0.0   1  01  겨울
# 3     2020-01-01   03   472    -5.6      0.0      0.0     0.0   1  01  겨울
# 4     2020-01-01   04   344    -5.4      0.0      0.0     0.0   1  01  겨울
# ...          ...  ...   ...     ...      ...      ...     ...  ..  ..  ..
# 8760  2020-12-31   19  1340    -7.1      0.0      2.4     0.0   1  12  겨울
# 8761  2020-12-31   20  1062    -7.1      0.0      3.2     0.0   1  12  겨울
# 8762  2020-12-31   21   900    -7.2      0.0      2.7     0.0   1  12  겨울
# 8763  2020-12-31   22   537    -7.4      0.0      2.5     0.0   1  12  겨울
# 8764  2020-12-31   23   459    -7.6      0.0      2.2     0.0   1  12  겨울
#
# [8765 rows x 10 columns]

# %%
data_1[data_1['적설(cm)']!=0]
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 비수준   월  계절
# 442   2020-01-19   10   441     1.0      0.0      0.7     0.3   1  01  겨울
# 835   2020-02-04   19   411     0.9      0.0      3.1     0.3   1  02  겨울
# 836   2020-02-04   20   538     0.0      0.0      4.7     0.7   1  02  겨울
# 837   2020-02-04   21   630    -1.3      1.5      6.1     0.7   2  02  겨울
# 838   2020-02-04   22   775    -2.3      0.0      2.6     0.7   1  02  겨울
# ...          ...  ...   ...     ...      ...      ...     ...  ..  ..  ..
# 8439  2020-12-18   10  1064    -0.8      0.0      2.1     0.6   1  12  겨울
# 8440  2020-12-18   11  1332    -0.3      0.0      3.2     0.6   1  12  겨울
# 8441  2020-12-18   12  1602    -0.4      0.0      3.6     0.6   1  12  겨울
# 8442  2020-12-18   13  1642     0.8      0.0      3.2     0.6   1  12  겨울
# 8443  2020-12-18   14  1869     1.0      0.0      3.3     0.5   1  12  겨울
#
# [206 rows x 10 columns]

# %%
data_1
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 비수준   월  계절
# 0     2020-01-01   00   599    -6.5      0.0      0.0     0.0   1  01  겨울
# 1     2020-01-01   01   847    -5.9      0.0      1.7     0.0   1  01  겨울
# 2     2020-01-01   02   748    -5.7      0.0      0.1     0.0   1  01  겨울
# 3     2020-01-01   03   472    -5.6      0.0      0.0     0.0   1  01  겨울
# 4     2020-01-01   04   344    -5.4      0.0      0.0     0.0   1  01  겨울
# ...          ...  ...   ...     ...      ...      ...     ...  ..  ..  ..
# 8760  2020-12-31   19  1340    -7.1      0.0      2.4     0.0   1  12  겨울
# 8761  2020-12-31   20  1062    -7.1      0.0      3.2     0.0   1  12  겨울
# 8762  2020-12-31   21   900    -7.2      0.0      2.7     0.0   1  12  겨울
# 8763  2020-12-31   22   537    -7.4      0.0      2.5     0.0   1  12  겨울
# 8764  2020-12-31   23   459    -7.6      0.0      2.2     0.0   1  12  겨울
#
# [8765 rows x 10 columns]

# %% [markdown]
# # 전시간대비 이용건수

# %%
ex=[0]

# %%
a=[data_1['이용건수'][i+1]-data_1['이용건수'][i] for i in range(len(data_1)-1)]

# %%
k=ex+a

# %%
data_1['전시간대비']=k

# %%
data_1.to_csv('data/data0823.csv')

# %%
data_2=data_1[(data_1['강수량(mm)']!=0) & (data_1['전시간대비']<0)]

# %%
data_2
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 우천여부     시간대  \
# 135   2020-01-06   15   370     3.7      0.1      4.5     0.0  yes  출/퇴근 외
# 141   2020-01-06   21   201     3.6      0.5      4.5     0.0  yes  출/퇴근 외
# 147   2020-01-07   03    44     4.6      2.1      4.5     0.0  yes  출/퇴근 외
# 153   2020-01-07   09   116     5.8      6.5      3.6     0.0  yes    출/퇴근
# 156   2020-01-07   12    36     6.4      2.4      4.3     0.0  yes  출/퇴근 외
# ...          ...  ...   ...     ...      ...      ...     ...  ...     ...
# 7733  2020-11-19   00   429    17.1      1.9      2.3     0.0  yes  출/퇴근 외
# 7736  2020-11-19   03   146    19.1      5.1      4.2     0.0  yes  출/퇴근 외
# 7805  2020-11-22   00   703     9.1      0.2      1.3     0.0  yes  출/퇴근 외
# 7808  2020-11-22   03   156     8.1      1.3      1.4     0.0  yes  출/퇴근 외
# 7811  2020-11-22   06    44     6.5      1.5      2.5     0.0  yes  출/퇴근 외
#
#        월  계절  전시간대비
# 135   01  겨울    -57
# 141   01  겨울    -94
# ...

# %%
sns.lineplot(x='강수량(mm)',y='전시간대비',data=data_1)
#plt.plot(x=data_2['강수량(mm)'],y=data_2['전시간대비'])
# Out:
# <AxesSubplot:xlabel='강수량(mm)', ylabel='전시간대비'>

# %%
data_2.corr()
# Out:
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)    적설(cm)     전시간대비
# 이용건수     1.000000  0.453933 -0.118645  0.105782 -0.101117 -0.473344
# 기온(°C)   0.453933  1.000000  0.108394  0.026460 -0.230359 -0.295641
# 강수량(mm) -0.118645  0.108394  1.000000  0.134461 -0.010782  0.080516
# 풍속(m/s)  0.105782  0.026460  0.134461  1.000000  0.101458 -0.033823
# 적설(cm)  -0.101117 -0.230359 -0.010782  0.101458  1.000000  0.073755
# 전시간대비   -0.473344 -0.295641  0.080516 -0.033823  0.073755  1.000000

# %%
data_2[data_2['전시간대비']==]
# Out:
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)    적설(cm)     전시간대비
# 이용건수     1.000000  0.190052 -0.170942 -0.152042 -0.037664  0.436715
# 기온(°C)   0.190052  1.000000  0.096862 -0.193157 -0.372591  0.016256
# 강수량(mm) -0.170942  0.096862  1.000000  0.186861 -0.046318 -0.013889
# 풍속(m/s) -0.152042 -0.193157  0.186861  1.000000  0.062418 -0.041180
# 적설(cm)  -0.037664 -0.372591 -0.046318  0.062418  1.000000  0.011653
# 전시간대비    0.436715  0.016256 -0.013889 -0.041180  0.011653  1.000000

# %%
data_2=data_1[data_1['계절']=='여름']
data_2
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 비수준   월  계절  \
# 3648  2020-06-01   00   790    17.6      0.8      2.5     0.0   1  06  여름
# 3649  2020-06-01   01   915    17.7      0.3      2.9     0.0   1  06  여름
# 3650  2020-06-01   02   688    17.5      0.0      3.2     0.0   1  06  여름
# 3651  2020-06-01   03   506    17.1      0.0      3.2     0.0   1  06  여름
# 3652  2020-06-01   04   352    17.0      0.0      3.3     0.0   1  06  여름
# ...          ...  ...   ...     ...      ...      ...     ...  ..  ..  ..
# 5832  2020-08-31   19  8195    28.0      0.0      3.5     0.0   1  08  여름
# 5833  2020-08-31   20  7632    27.6      0.0      2.5     0.0   1  08  여름
# 5834  2020-08-31   21  7128    27.1      0.0      2.4     0.0   1  08  여름
# 5835  2020-08-31   22  5118    26.8      0.0      2.3     0.0   1  08  여름
# 5836  2020-08-31   23  2982    26.6      0.0      2.9     0.0   1  08  여름
#
#       전시간대비     시간대
# 3648    225  출/퇴근 외
# 3649    125  출/퇴근 외
# ...

# %%
sns.boxplot(x='월',y='이용건수',data=data_2)
# Out:
# <AxesSubplot:xlabel='월', ylabel='이용건수'>

# %%
data_2.corr()
# Out:
#              이용건수    기온(°C)   강수량(mm)   풍속(m/s)  적설(cm)     전시간대비
# 이용건수     1.000000  0.352716 -0.246798  0.150811     NaN  0.229089
# 기온(°C)   0.352716  1.000000 -0.112864  0.138099     NaN  0.137211
# 강수량(mm) -0.246798 -0.112864  1.000000  0.172656     NaN  0.005724
# 풍속(m/s)  0.150811  0.138099  0.172656  1.000000     NaN  0.125592
# 적설(cm)        NaN       NaN       NaN       NaN     NaN       NaN
# 전시간대비    0.229089  0.137211  0.005724  0.125592     NaN  1.000000

# %%
plt.plot(data_2['대여일자'])

# %%
data_1
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 비수준   월  계절  \
# 0     2020-01-01   00   599    -6.5      0.0      0.0     0.0   1  01  겨울
# 1     2020-01-01   01   847    -5.9      0.0      1.7     0.0   1  01  겨울
# 2     2020-01-01   02   748    -5.7      0.0      0.1     0.0   1  01  겨울
# 3     2020-01-01   03   472    -5.6      0.0      0.0     0.0   1  01  겨울
# 4     2020-01-01   04   344    -5.4      0.0      0.0     0.0   1  01  겨울
# ...          ...  ...   ...     ...      ...      ...     ...  ..  ..  ..
# 8760  2020-12-31   19  1340    -7.1      0.0      2.4     0.0   1  12  겨울
# 8761  2020-12-31   20  1062    -7.1      0.0      3.2     0.0   1  12  겨울
# 8762  2020-12-31   21   900    -7.2      0.0      2.7     0.0   1  12  겨울
# 8763  2020-12-31   22   537    -7.4      0.0      2.5     0.0   1  12  겨울
# 8764  2020-12-31   23   459    -7.6      0.0      2.2     0.0   1  12  겨울
#
#       전시간대비     시간대
# 0         0  출/퇴근 외
# 1       248  출/퇴근 외
# ...

# %%
df=pd.pivot_table(data_1,index='대여일자',values=['전시간대비']).reset_index()

# %%
sns.boxplot(data=data_fin,x='계절',y='이용건수')
# Out:
# <AxesSubplot:xlabel='계절', ylabel='이용건수'>

# %%
pd.pivot_table(data_1,index='연령대')
# Out:
#             대여일자 대여시간  이용건수  기온(°C)  강수량(mm)  풍속(m/s)  적설(cm) 비수준   월  계절  \
# 0     2020-01-01   00   599    -6.5      0.0      0.0     0.0   1  01  겨울
# 1     2020-01-01   01   847    -5.9      0.0      1.7     0.0   1  01  겨울
# 2     2020-01-01   02   748    -5.7      0.0      0.1     0.0   1  01  겨울
# 3     2020-01-01   03   472    -5.6      0.0      0.0     0.0   1  01  겨울
# 4     2020-01-01   04   344    -5.4      0.0      0.0     0.0   1  01  겨울
# ...          ...  ...   ...     ...      ...      ...     ...  ..  ..  ..
# 8760  2020-12-31   19  1340    -7.1      0.0      2.4     0.0   1  12  겨울
# 8761  2020-12-31   20  1062    -7.1      0.0      3.2     0.0   1  12  겨울
# 8762  2020-12-31   21   900    -7.2      0.0      2.7     0.0   1  12  겨울
# 8763  2020-12-31   22   537    -7.4      0.0      2.5     0.0   1  12  겨울
# 8764  2020-12-31   23   459    -7.6      0.0      2.2     0.0   1  12  겨울
#
#       전시간대비     시간대
# 0         0  출/퇴근 외
# 1       248  출/퇴근 외
# ...

# %% [markdown]
# # 성별/연령

# %% [markdown]
# ## 전처리

# %%
test=pd.read_csv('data/total_1.csv',index_col=0)

# %%
test
# Out:
#          대여시간   성별 연령대코드  이용건수
# 0           0  NaN  ~10대     1
# 1           0  NaN  ~10대     1
# 2           0  NaN  ~10대     1
# 3           0  NaN  ~10대     1
# 4           0  NaN  ~10대     1
# ...       ...  ...   ...   ...
# 1066896    23    M   30대     1
# 1066897    23    M   30대     1
# 1066898    23    M   30대     1
# 1066899    23    M   50대     1
# 1066900    23  NaN   20대     4
#
# [19026035 rows x 4 columns]

# %%
t=[]
for i in test.대여시간:
    i=str(i)
    if len(i)==1:
        t.append('0'+i)
    else :
        t.append(i)

test['대여시간']=t
test
# Out:
#         대여시간   성별 연령대코드  이용건수     시간대
# 0         00  NaN  ~10대     1  출/퇴근 외
# 1         00  NaN  ~10대     1  출/퇴근 외
# 2         00  NaN  ~10대     1  출/퇴근 외
# 3         00  NaN  ~10대     1  출/퇴근 외
# 4         00  NaN  ~10대     1  출/퇴근 외
# ...      ...  ...   ...   ...     ...
# 1066896   23    M   30대     1  출/퇴근 외
# 1066897   23    M   30대     1  출/퇴근 외
# 1066898   23    M   30대     1  출/퇴근 외
# 1066899   23    M   50대     1  출/퇴근 외
# 1066900   23  NaN   20대     4  출/퇴근 외
#
# [19026035 rows x 5 columns]

# %%
test['시간대']=['출/퇴근' if i=='07' or i=='08' or i=='09' or i=='17' or i=='18' or i=='19' else '출/퇴근 외' for i in test['대여시간']]

# %%
test.fillna('미기입',inplace=True)

# %%
a=test['성별']

# %%
b=[i.upper() for i in a]

# %%
test['성별']=b

# %%
test
# Out:
#         대여시간   성별 연령대코드  이용건수     시간대
# 0         00  미기입  ~10대     1  출/퇴근 외
# 1         00  미기입  ~10대     1  출/퇴근 외
# 2         00  미기입  ~10대     1  출/퇴근 외
# 3         00  미기입  ~10대     1  출/퇴근 외
# 4         00  미기입  ~10대     1  출/퇴근 외
# ...      ...  ...   ...   ...     ...
# 1066896   23    M   30대     1  출/퇴근 외
# 1066897   23    M   30대     1  출/퇴근 외
# 1066898   23    M   30대     1  출/퇴근 외
# 1066899   23    M   50대     1  출/퇴근 외
# 1066900   23  미기입   20대     4  출/퇴근 외
#
# [19026035 rows x 5 columns]

# %% [markdown]
# ## 성별 이용건수

# %%
sex=pd.pivot_table(test,index=['연령대코드','성별'],values='이용건수',aggfunc='sum')

# %%
sex
# Out:
#               이용건수
# 연령대코드 성별
# 20대   F    2100239
#       M    2396664
#       미기입  6188092
# 30대   F    1071582
#       M    1768193
#       미기입  2495780
# 40대   F     553687
#       M    1193598
#       미기입  1624723
# 50대   F     301393
#       M     666692
#       미기입   960497
# 60대   F      59346
#       M     196209
#       미기입   235937
# 70대~  F      24083
#       M      33558
#       미기입    29646
# ~10대  F     185674
#       M     342167
#       미기입   843987

# %%
#total=pd.read_csv('data/total.csv',index_col=0)

# %%
sex2=sex.reset_index()

# %%
sex3=sex2[sex2['성별']!='미기입']
sex3
# Out:
#    연령대코드 성별     이용건수
# 0    20대  F  2100239
# 1    20대  M  2396664
# 3    30대  F  1071582
# 4    30대  M  1768193
# 6    40대  F   553687
# 7    40대  M  1193598
# 9    50대  F   301393
# 10   50대  M   666692
# 12   60대  F    59346
# 13   60대  M   196209
# 15  70대~  F    24083
# 16  70대~  M    33558
# 18  ~10대  F   185674
# 19  ~10대  M   342167

# %%
sns

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x='연령대코드',y='이용건수',hue='성별',data=sex3)
# Out:
# <AxesSubplot:xlabel='연령대코드', ylabel='이용건수'>

# %%
gender=pd.pivot_table(test,index='대여시간',columns='성별',values='이용건수',aggfunc='sum')

# %%
gender2=gender[['M','F']]
gender2.plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='대여시간'>

# %% [markdown]
# ## 시간대/연령대별

# %%
tt=pd.pivot_table(test,index=['연령대코드','시간대'],values='이용건수',aggfunc='sum').reset_index()

# %%
tt['시간 당 이용건수']=tt['이용건수']/pd.Series(([6,18]*7))

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x='연령대코드',y='시간 당 이용건수',hue='시간대',data=tt)
plt.ylabel('시간 당 이용건수')
plt.xlabel('연령대')
# Out:
# <AxesSubplot:xlabel='연령대코드', ylabel='시간 당 이용건수'>
# Text(0, 0.5, '시간 당 이용건수')
# Text(0.5, 0, '연령대')

# %%
tt2=tt

# %%
tt2['연령대코드']=['10대 이전' if i=='~10대' else i for i in tt['연령대코드']]

# %%
tt2=tt2.sort_values('연령대코드')

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x='연령대코드',y='시간 당 이용건수',hue='시간대',data=tt2)
plt.ylabel('시간 당 이용건수')
plt.xlabel('연령대')
# Out:
# <AxesSubplot:xlabel='연령대코드', ylabel='시간 당 이용건수'>
# Text(0, 0.5, '시간 당 이용건수')
# Text(0.5, 0, '연령대')

# %%
age=pd.pivot_table(test,index='대여시간',columns='연령대코드',values='이용건수',aggfunc='sum')

# %%
age.plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='대여시간'>

# %% [markdown]
# ## 일자일시별 통합

# %%
total_1=pd.read_csv('data/total.csv',index_col=0)

# %%
total_1=total_1[['대여일자','대여시간','성별','연령대코드','이용건수']]

# %%
total_1
# Out:
#                대여일자  대여시간   성별 연령대코드  이용건수
# 0        2020-01-01     0  NaN  ~10대     1
# 1        2020-01-01     0  NaN  ~10대     1
# 2        2020-01-01     0  NaN  ~10대     1
# 3        2020-01-01     0  NaN  ~10대     1
# 4        2020-01-01     0  NaN  ~10대     1
# ...             ...   ...  ...   ...   ...
# 1066896  2020-12-31    23    M   30대     1
# 1066897  2020-12-31    23    M   30대     1
# 1066898  2020-12-31    23    M   30대     1
# 1066899  2020-12-31    23    M   50대     1
# 1066900  2020-12-31    23  NaN   20대     4
#
# [19026035 rows x 5 columns]

# %%
t=[]
for i in total_1.대여시간:
    i=str(i)
    if len(i)==1:
        t.append('0'+i)
    else :
        t.append(i)

total_1['대여시간']=t


total_1['시간대']=['출/퇴근' if i=='07' or i=='08' or i=='09' or i=='17' or i=='18' or i=='19' else '출/퇴근 외' for i in total_1['대여시간']]

total_1.fillna('미기입',inplace=True)

a=total_1['성별']

b=[i.upper() for i in a]

total_1['성별']=b
# Out:
#         대여시간   성별 연령대코드  이용건수     시간대
# 0         00  미기입  ~10대     1  출/퇴근 외
# 1         00  미기입  ~10대     1  출/퇴근 외
# 2         00  미기입  ~10대     1  출/퇴근 외
# 3         00  미기입  ~10대     1  출/퇴근 외
# 4         00  미기입  ~10대     1  출/퇴근 외
# ...      ...  ...   ...   ...     ...
# 1066896   23    M   30대     1  출/퇴근 외
# 1066897   23    M   30대     1  출/퇴근 외
# 1066898   23    M   30대     1  출/퇴근 외
# 1066899   23    M   50대     1  출/퇴근 외
# 1066900   23  미기입   20대     4  출/퇴근 외
#
# [19026035 rows x 5 columns]

# %%
total_1['성별']=test['성별']
total_1['대여시간']=test['대여시간']
# Out:
# C:\Users\JungHun.DESKTOP-JRGUSS9\AppData\Local\Temp\ipykernel_4228\4185584140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_1['성별']=test['성별']
# C:\Users\JungHun.DESKTOP-JRGUSS9\AppData\Local\Temp\ipykernel_4228\4185584140.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_1['대여시간']=test['대여시간']

# %%
total_1.to_csv('data/total_2.csv')

# %%
g=pd.pivot_table(total_1,index=['대여일자','대여시간'],columns='성별',values='이용건수',aggfunc='sum')

# %%
g
# Out:
# 성별                   F      M    미기입
# 대여일자       대여시간
# 2020-01-01 00     52.0  200.0  347.0
#            01     80.0  277.0  490.0
#            02     93.0  242.0  413.0
#            03     34.0  158.0  280.0
#            04     28.0  111.0  205.0
# ...                ...    ...    ...
# 2020-12-31 19    222.0  510.0  608.0
#            20    179.0  418.0  465.0
#            21    142.0  332.0  426.0
#            22     71.0  192.0  274.0
#            23     56.0  182.0  221.0
#
# [8765 rows x 3 columns]

# %%
ag=pd.pivot_table(total_1,index=['대여일자','대여시간'],columns='연령대코드',values='이용건수',aggfunc='sum')

# %%
ag
# Out:
# 연령대코드              20대    30대    40대    50대   60대  70대~  ~10대
# 대여일자       대여시간
# 2020-01-01 00    302.0  117.0   78.0   41.0  10.0   3.0  48.0
#            01    430.0  172.0   82.0   86.0  21.0   3.0  53.0
#            02    394.0  127.0   67.0   86.0  35.0   3.0  36.0
#            03    188.0   77.0   60.0   60.0  35.0   3.0  49.0
#            04    166.0   38.0   31.0   49.0  14.0   5.0  41.0
# ...                ...    ...    ...    ...   ...   ...   ...
# 2020-12-31 19    493.0  382.0  247.0  121.0  40.0   3.0  54.0
#            20    404.0  324.0  145.0  102.0  26.0   2.0  59.0
#            21    402.0  221.0  116.0   96.0  16.0   2.0  47.0
#            22    240.0  125.0   73.0   61.0  14.0   1.0  23.0
#            23    209.0  109.0   56.0   49.0  16.0   2.0  18.0
#
# [8765 rows x 7 columns]
